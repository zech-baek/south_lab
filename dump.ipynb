# %%
from project.get_device_info import get_map
from misc.dcic_parsing import parsing

log_parsing = parsing()

# %%
file = "dumpState_FAB0_S948BFAU1AYL5_202512091430.log"
dev = "sc8583"
rev = "1p1"

log_parsing.start_parsing(dump=f"./log/{file}", device=dev, revision=rev, vendor_keyword=True)
