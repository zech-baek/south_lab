# %%
from misc.dcic_parsing import parsing
log_parsing = parsing()

import os

log_path = "./log"
list_log_file = [f for f in os.listdir(log_path) if os.path.isfile(os.path.join(log_path, f))]

for log_file in list_log_file:

    keyword = "./misc/dcic_keyword.yaml"
    dev = "sc8583"
    rev = "1p1"

    log_parsing.start_parsing(dump=f"./log/{log_file}", keyword=keyword, device=dev, revision=rev, vendor_keyword=True)

    print(f"\nprocessing done : {log_file}\n\n\n\n\n\n")
# Out:
# ,---.                   ,--.  ,--.           ,--.     ,--.                      ,--.                       ,---.                  ,--.
# '   .-'  ,---. ,--.,--.,-'  '-.|  ,---.  ,---.|  ,---. `--' ,---.     ,-----.    |  |    ,---.  ,---.      /  O  \ ,--,--,  ,--,--.|  |,--. ,--.,-----. ,---. ,--.--.
# `.  `-. | .-. ||  ||  |'-.  .-'|  .-.  || .--'|  .-.  |,--.| .-. |    '-----'    |  |   | .-. || .-. |    |  .-.  ||      ' ,-.  ||  | \  '  / `-.  / | .-. :|  .--'
# .-'    |' '-' ''  ''  '  |  |  |  | |  |\ `--.|  | |  ||  || '-' '               |  '--.' '-' '' '-' '    |  | |  ||  ||  |\ '-'  ||  |  \   '   /  `-.\   --.|  |
# `-----'  `---'  `----'   `--'  `--' `--' `---'`--' `--'`--'|  |-'                `-----' `---' .`-  /     `--' `--'`--''--' `--`--'`--'.-'  /   `-----' `----'`--'
#                                                            `--'                                `---'                                   `---'                       JY™
# [  0.00%]  start dump parsing    -> save to ./log\20260212_102028 - dumpState_FAB0_S948UFAU1AZA6_202601131605_vendor_parsing.log
# [  0.00%]  start adc log         -> save to ./log\20260212_102028 - dumpState_FAB0_S948UFAU1AZA6_202601131605_vendor_parsing_adc.log
# [  0.00%]  start parsing comment -> save to ./log\20260212_102028 - dumpState_FAB0_S948UFAU1AZA6_202601131605_vendor_comments.txt
# [  0.00%]  bootloader version : Kernel: Linux version 6.12.30-android16-5-p8431431-abogkiFAB0_S948UFAU1AZA6-4k (kleaf@build-host) (Android (14043575, +pgo, +bolt, +lto, +mlgo, based on r536225) clang version 19.0.1 (https://android.googlesource.com/toolchain/llvm-project b3a530ec6537146650e42be89f1089e9a3588460), LLD 19.0.1) #1 SMP PREEMPT Tue Jan 13 07:05:10 UTC 2026
# [  0.01%]  bootloader version : androidboot.bootloader = "FAB0_S948UFAU1AZA6"
# [  0.01%]  bootloader version : androidboot.bootloader = "FAB0_S948UFAU1AZA6"
# [  0.02%]  Kernel version : # Parameters from bootloader:
# [  0.76%]  SC_REL : 1.48
# [  0.82%]  warning flag -- [  574.582648] [0:  kworker/u32:7: 1292] sc8583-charger 3-006e: trigger :cp switching flag
# [  0.82%]  warning flag -- [  574.583161] [0:  kworker/u32:7: 1292] sc8583-charger 3-006e: trigger :iin ucp rise flag
# [  0.82%]  warning flag -- [  574.583165] [0:  kworker/u32:7: 1292] sc8583-charger 3-006e: trigger :vbat reg active flag
# [  0.98%]  IOUT current read : [  578.607767] [5:      Thread-25:10753] sec_bat_show_attrs: batt_current_ua_now (8597656)
# [  0.99%]  IOUT current read : [  579.028452] [5:      Thread-25:10753] sec_bat_show_attrs: batt_current_ua_now (8609375)
# [  1.00%]  IOUT current read : [  579.448985] [5:      Thread-25:10753] sec_bat_show_attrs: batt_current_ua_now (8605468)
# [  1.02%]  IOUT current read : [  579.872389] [1:      Thread-25:10753] sec_bat_show_attrs: batt_current_ua_now (8700000)
# [  1.02%]  IOUT current read : [  580.296867] [4:      Thread-25:10753] sec_bat_show_attrs: batt_current_ua_now (8720312)
# [  1.03%]  warning flag -- [  580.811153] [0:  kworker/u32:7: 1292] sc8583-charger 3-006e: trigger :vext ovp flag
# [  1.21%]  IOUT current read : [  585.768729] [4:      Thread-26:10800] sec_bat_show_attrs: batt_current_ua_now (8778906)
# [  1.22%]  IOUT current read : [  586.188648] [1:      Thread-26:10800] sec_bat_show_attrs: batt_current_ua_now (8739062)
# [  1.22%]  IOUT current read : [  586.612823] [0:      Thread-26:10800] sec_bat_show_attrs: batt_current_ua_now (8835156)
# [  1.23%]  IOUT current read : [  587.036950] [0:      Thread-26:10800] sec_bat_show_attrs: batt_current_ua_now (8771093)
# [  1.23%]  IOUT current read : [  587.456818] [1:      Thread-26:10800] sec_bat_show_attrs: batt_current_ua_now (8771093)
# [  1.26%]  Kernel version : [  587.933960] [3:crtc_commit:211: 1583] [SDE_0] ss_module_info_read : cell_id both bootloader & kernel match
# [  5.88%]  bootloader version : 01-01 09:04:51.882  root     0     0 I         : Linux version 6.12.30-android16-5-p8431431-abogkiFAB0_S948UFAU1AZA6-4k (kleaf@build-host) (Android (14043575, +pgo, +bolt, +lto, +mlgo, based on r536225) clang version 19.0.1 (https://android.googlesource.com/toolchain/llvm-project b3a530ec6537146650e42be89f1089e9a3588460), LLD 19.0.1) #1 SMP PREEMPT Tue Jan 13 07:05:10 UTC 2026
# [  6.08%]  Kernel version : 01-01 09:04:52.651  root     1     1 I fsck.f2fs: Running fsck.f2fs on /dev/block/by-name/metadata
# [  6.08%]  bootloader version : 01-01 09:04:52.651  root     1     1 I fsck.f2fs: "6.12.30-android16-5-p8431431-abogkiFAB0_S948UFAU1AZA6-4k"
# [  6.08%]  Kernel version : 01-01 09:04:52.651  root     1     1 I fsck.f2fs: Info: /dev/block/by-name/metadata 16384 blocks, 246 files, 247/232960 nodes, 303/5120 blocks, 8 SPO cnt
# [  7.28%]  Kernel version : 01-01 09:04:57.067  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 10.77%]  Kernel version : 01-13 15:56:04.221  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 12.26%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 12.75%]  Kernel version : 01-13 15:57:04.711  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 15.75%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 18.69%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 19.25%]  Kernel version : 01-13 15:59:50.027  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 21.41%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 28.77%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 29.23%]  Kernel version : 01-13 16:03:51.021  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 34.95%]  warning flag -- 01-13 16:05:14.380  root  1292  1292 E sc8583-charger 3-006e: trigger :cp switching flag
# [ 34.95%]  warning flag -- 01-13 16:05:14.381  root  1292  1292 E sc8583-charger 3-006e: trigger :iin ucp rise flag
# [ 34.95%]  warning flag -- 01-13 16:05:14.381  root  1292  1292 E sc8583-charger 3-006e: trigger :vbat reg active flag
# [ 35.23%]  IOUT current read : 01-13 16:05:18.406  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8597656)
# [ 35.25%]  IOUT current read : 01-13 16:05:18.826  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8609375)
# [ 35.27%]  IOUT current read : 01-13 16:05:19.247  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8605468)
# [ 35.29%]  IOUT current read : 01-13 16:05:19.670  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8700000)
# [ 35.29%]  IOUT current read : 01-13 16:05:20.095  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8720312)
# [ 35.31%]  warning flag -- 01-13 16:05:20.609  root  1292  1292 E sc8583-charger 3-006e: trigger :vext ovp flag
# [ 35.52%]  IOUT current read : 01-13 16:05:25.567  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8778906)
# [ 35.53%]  IOUT current read : 01-13 16:05:25.986  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8739062)
# [ 35.54%]  IOUT current read : 01-13 16:05:26.411  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8835156)
# [ 35.57%]  IOUT current read : 01-13 16:05:26.835  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8771093)
# [ 35.59%]  IOUT current read : 01-13 16:05:27.255  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8771093)
# [ 35.82%]  Kernel version : 01-13 16:05:27.732  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 42.84%]  bootloader version : 01-01 09:04:51.882  root     0     0 I         : Linux version 6.12.30-android16-5-p8431431-abogkiFAB0_S948UFAU1AZA6-4k (kleaf@build-host) (Android (14043575, +pgo, +bolt, +lto, +mlgo, based on r536225) clang version 19.0.1 (https://android.googlesource.com/toolchain/llvm-project b3a530ec6537146650e42be89f1089e9a3588460), LLD 19.0.1) #1 SMP PREEMPT Tue Jan 13 07:05:10 UTC 2026
# [ 43.04%]  Kernel version : 01-01 09:04:52.651  root     1     1 I fsck.f2fs: Running fsck.f2fs on /dev/block/by-name/metadata
# [ 43.04%]  bootloader version : 01-01 09:04:52.651  root     1     1 I fsck.f2fs: "6.12.30-android16-5-p8431431-abogkiFAB0_S948UFAU1AZA6-4k"
# [ 43.04%]  Kernel version : 01-01 09:04:52.651  root     1     1 I fsck.f2fs: Info: /dev/block/by-name/metadata 16384 blocks, 246 files, 247/232960 nodes, 303/5120 blocks, 8 SPO cnt
# [ 43.98%]  Kernel version : 01-01 09:04:57.067  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 44.58%]  Kernel version : 01-13 15:56:04.221  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 44.83%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 44.93%]  Kernel version : 01-13 15:57:04.711  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 45.53%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 46.07%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 46.18%]  Kernel version : 01-13 15:59:50.027  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 46.56%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 47.83%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic Not matched, cp Not matched, vbat Not matched, pd Not matched, wpc Not matched
# [ 47.93%]  Kernel version : 01-13 16:03:51.021  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 49.57%]  warning flag -- 01-13 16:05:14.380  root  1292  1292 E sc8583-charger 3-006e: trigger :cp switching flag
# [ 49.57%]  warning flag -- 01-13 16:05:14.381  root  1292  1292 E sc8583-charger 3-006e: trigger :iin ucp rise flag
# [ 49.57%]  warning flag -- 01-13 16:05:14.381  root  1292  1292 E sc8583-charger 3-006e: trigger :vbat reg active flag
# [ 49.73%]  IOUT current read : 01-13 16:05:18.406  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8597656)
# [ 49.73%]  IOUT current read : 01-13 16:05:18.826  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8609375)
# [ 49.75%]  IOUT current read : 01-13 16:05:19.247  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8605468)
# [ 49.77%]  IOUT current read : 01-13 16:05:19.670  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8700000)
# [ 49.77%]  IOUT current read : 01-13 16:05:20.095  1000 10753 10753 E sec_bat_show_attrs: batt_current_ua_now (8720312)
# [ 49.78%]  warning flag -- 01-13 16:05:20.609  root  1292  1292 E sc8583-charger 3-006e: trigger :vext ovp flag
# [ 49.96%]  IOUT current read : 01-13 16:05:25.567  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8778906)
# [ 49.97%]  IOUT current read : 01-13 16:05:25.986  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8739062)
# [ 49.97%]  IOUT current read : 01-13 16:05:26.411  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8835156)
# [ 49.98%]  IOUT current read : 01-13 16:05:26.835  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8771093)
# [ 49.98%]  IOUT current read : 01-13 16:05:27.255  1000 10800 10800 E sec_bat_show_attrs: batt_current_ua_now (8771093)
# [ 50.01%]  Kernel version : 01-13 16:05:27.732  root  1583  1583 I [SDE_0] ss_module_info_read: cell_id both bootloader & kernel match
# [ 50.96%]  Kernel version : [    0.769107] [      fsck.f2fs,   204] <fsck.f2fs> Running fsck.f2fs on /dev/block/by-name/metadata
# [ 50.96%]  Kernel version : [    0.769928] [      fsck.f2fs,   204] <fsck.f2fs> Info: /dev/block/by-name/metadata 16384 blocks, 246 files, 247/232960 nodes, 303/5120 blocks, 8 SPO cnt
# [ 53.62%]  Kernel version : [ro.boot.bootloader]: [FAB0_S948UFAU1AZA6]
# [ 53.63%]  Kernel version : [ro.bootloader]: [FAB0_S948UFAU1AZA6]
# [ 55.39%]  LAST KMSG : ------ LAST KMSG (/proc/last_kmsg) ------
# [ 55.57%]  IOUT current read : [  139.952252] [0:      2:1Reader: 6446] sec_bat_show_attrs: batt_current_ua_now (-42968)
# [ 55.57%]  IOUT current read : [  140.367780] [0:      2:1Reader: 6446] sec_bat_show_attrs: batt_current_ua_now (-40625)
# [ 55.57%]  IOUT current read : [  140.781052] [4:      2:1Reader: 6446] sec_bat_show_attrs: batt_current_ua_now (-40625)
# [ 55.57%]  IOUT current read : [  141.193498] [0:      2:1Reader: 6446] sec_bat_show_attrs: batt_current_ua_now (-32812)
# [ 55.57%]  IOUT current read : [  141.605161] [5:      2:1Reader: 6446] sec_bat_show_attrs: batt_current_ua_now (-38281)
# [ 55.63%]  Kernel version : [  142.445570] [2:crtc_commit:211: 1594] [SDE_0] ss_module_info_read : cell_id both bootloader & kernel match
# [ 55.68%]  Kernel version : [  144.104969] [3:crtc_commit:211: 1594] [SDE_0] ss_module_info_read : cell_id both bootloader & kernel match
# [ 56.12%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic VEXT1 OVLO, cp VEXT1 OVLO, vbat Not matched, pd Not matched, wpc Not matched
# [ 56.51%]  POWER_SUPPLY_EXT_PROP_DC_ERROR_CAUSE : dcic VEXT1 OVLO, cp VEXT1 OVLO, vbat Not matched, pd Not matched, wpc Not matched
# [ 56.61%]  Kernel version : [  254.797174] [0:crtc_commit:211: 1594] [SDE_0] ss_module_info_read : cell_id both bootloader & kernel match
# [ 57.36%]  Kernel version : [004f5460a][3]T [secretkeeper::isecretkeeper:116] -- Received ISecretKeeper_process_bootloader() command
# [ 57.36%]  Kernel version : [004f5497e][3]T [secretkeeper::isecretkeeper:131] -- Finished processing ISecretKeeper_process_bootloader() command
# [ 57.37%]  Kernel version : { 5466454 }[ ABL ] [BLDP] bootloader_mode = 0
# [ 57.37%]  Kernel version : { 5466484 }[ ABL ] [BLDP] bootloader_event_target[] =
# [ 57.37%]  Kernel version : { 5466484 }[ ABL ] [BLDP] bootloader_event = 0x0
# [ 57.37%]  Kernel version : { 5466484 }[ ABL ] [BLDP] bootloader_rp = 0x1
# [ 57.38%]  Kernel version : { 5496496 }[ ABL ] [BLDP] bootloader_mode = 0
# [ 57.38%]  Kernel version : { 5496496 }[ ABL ] [BLDP] bootloader_event_target[] =
# [ 57.38%]  Kernel version : { 5496527 }[ ABL ] [BLDP] bootloader_event = 0x0
# [ 57.38%]  Kernel version : { 5496527 }[ ABL ] [BLDP] bootloader_rp = 0x1
# [ 57.39%]  LAST KMSG : ------ 0.002s was the duration of 'LAST KMSG' ------
# [ 62.77%]  Kernel version :         "name": "RELEASE_BOOTLOADER_DETERMINISTIC_AVB_SALT",
# [ 62.77%]  Kernel version :         "description": "If true, a deterministic salt will be used in the avb signed bootloader.img partitions.",
# [ 63.40%]  Kernel version :         "name": "RELEASE_BOOTLOADER_DETERMINISTIC_AVB_SALT",
# [ 63.40%]  Kernel version :         "description": "If true, a deterministic salt will be used in the avb signed bootloader.img partitions.",
# [ 63.88%]  Kernel version :         "name": "RELEASE_BOOTLOADER_DETERMINISTIC_AVB_SALT",
# [ 63.88%]  Kernel version :         "description": "If true, a deterministic salt will be used in the avb signed bootloader.img partitions.",
# [100.00%] finish dump and adc parsing, clear the parameters
#
# processing done : dumpState_FAB0_S948UFAU1AZA6_202601131605.log

# %%
log_path = "./log"

# %%
list_log_file = [f for f in os.listdir(log_path) if os.path.isfile(os.path.join(log_path, f))]

for log_file in list_log_file:

    keyword = "./misc/dcic_keyword.yaml"
    dev = "sc8583"
    rev = "1p1"

    log_parsing.start_parsing(dump=f"./log/{log_file}", keyword=keyword, device=dev, revision=rev, vendor_keyword=True)

    print(f"\nprocessing done : {log_file}\n\n\n\n\n\n")

# %%
# First install: pip install tqdm
from tqdm import tqdm
import time

for i in tqdm(range(100), desc="Loading", unit="%"):
    time.sleep(0.05)  # Simulate work

# %%
import time
import sys

def animated_progress(total=100, width=50):
    for i in range(total + 1):
        # Calculate progress
        percentage = i
        filled = int(width * i // total)
        bar = '█' * filled + '░' * (width - filled)
        
        # Print on same line
        sys.stdout.write(f'\r|{bar}| {percentage:3d}%')
        sys.stdout.flush()
        time.sleep(0.05)
    
    print()  # New line after completion

animated_progress()
