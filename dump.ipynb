# %%
from misc.dcic_parsing import parsing
log_parsing = parsing()

import os

log_path = "./log"
list_log_file = [f for f in os.listdir(log_path) if os.path.isfile(os.path.join(log_path, f))]

for log_file in list_log_file:

    keyword = "./misc/dcic_keyword.yaml"
    dev = "sc8583"
    rev = "1p1"

    log_parsing.start_parsing(dump=f"./log/{log_file}", keyword=keyword, device=dev, revision=rev, vendor_keyword=True)

    print(f"\nprocessing done : {log_file}\n\n\n\n\n\n")
# Out:
# ,---.                   ,--.  ,--.           ,--.     ,--.                      ,--.                       ,---.                  ,--.
# '   .-'  ,---. ,--.,--.,-'  '-.|  ,---.  ,---.|  ,---. `--' ,---.     ,-----.    |  |    ,---.  ,---.      /  O  \ ,--,--,  ,--,--.|  |,--. ,--.,-----. ,---. ,--.--.
# `.  `-. | .-. ||  ||  |'-.  .-'|  .-.  || .--'|  .-.  |,--.| .-. |    '-----'    |  |   | .-. || .-. |    |  .-.  ||      ' ,-.  ||  | \  '  / `-.  / | .-. :|  .--'
# .-'    |' '-' ''  ''  '  |  |  |  | |  |\ `--.|  | |  ||  || '-' '               |  '--.' '-' '' '-' '    |  | |  ||  ||  |\ '-'  ||  |  \   '   /  `-.\   --.|  |
# `-----'  `---'  `----'   `--'  `--' `--' `---'`--' `--'`--'|  |-'                `-----' `---' .`-  /     `--' `--'`--''--' `--`--'`--'.-'  /   `-----' `----'`--'
#                                                         `--'                                `---'                                   `---'                          JY™
# [  0.00%]  start dump parsing    -> save to ./log\20260203_172812 - P260130-01628_analysis_vendor_parsing.md
# [  0.00%]  start adc log         -> save to ./log\20260203_172812 - P260130-01628_analysis_vendor_parsing_adc.md
# [  0.00%]  start parsing comment -> save to ./log\20260203_172812 - P260130-01628_analysis_vendor_comments.txt
# [ 24.24%]  warning flag -- [    5.495403] [4:  kworker/u32:7: 1304] sc8583-charger 3-006e: trigger :cp switching flag
# [ 24.75%]  warning flag -- [    5.495720] [4:  kworker/u32:7: 1304] sc8583-charger 3-006e: trigger :qb1 on flag
# [ 25.25%]  warning flag -- [    5.495976] [4:  kworker/u32:7: 1304] sc8583-charger 3-006e: trigger :vbat reg active flag
# [ 25.76%]  warning flag -- [    5.496654] [5:  kworker/u32:7: 1304] sc8583-charger 3-006e: trigger :c1p2out uvp flag
# [100.00%] finish dump and adc parsing, clear the parameters
#
# processing done : P260130-01628_analysis.md

# %%
# First install: pip install tqdm
from tqdm import tqdm
import time

for i in tqdm(range(100), desc="Loading", unit="%"):
    time.sleep(0.05)  # Simulate work

# %%
import time
import sys

def animated_progress(total=100, width=50):
    for i in range(total + 1):
        # Calculate progress
        percentage = i
        filled = int(width * i // total)
        bar = '█' * filled + '░' * (width - filled)
        
        # Print on same line
        sys.stdout.write(f'\r|{bar}| {percentage:3d}%')
        sys.stdout.flush()
        time.sleep(0.05)
    
    print()  # New line after completion

animated_progress()
