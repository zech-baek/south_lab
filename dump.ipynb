# %%
from project.get_device_info import get_map
from misc.dcic_parsing import parsing

log_parsing = parsing()

# %%
file = "./log/dump2.txt"
dev = "sc8583"
rev = "1p1"

log_parsing.start_parsing(dump=file, device=dev, revision=rev, vendor_keyword=True)
# Out:
# [20251214_163036] start dump parsing    -> save to ./log\20251214_163036 - dump2_vendor_parsing.txt
# [20251214_163036] start adc log         -> save to ./log\20251214_163036 - dump2_vendor_parsing_adc.txt
# [20251214_163036] start parsing comment -> save to ./log\20251214_163036 - dump2_vendor_comments.txt
# [20251214_163036] finish dump and adc parsing, clear the parameters
