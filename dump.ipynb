# %%
from misc.dcic_parsing import parsing
log_parsing = parsing()

import os

log_path = "./log"
list_log_file = [f for f in os.listdir(log_path) if os.path.isfile(os.path.join(log_path, f))]

for log_file in list_log_file:

    keyword = "./misc/dcic_keyword.yaml"
    dev = "sc8563"
    rev = "1p1"

    log_parsing.start_parsing(dump=f"./log/{log_file}", keyword=keyword, device=dev, revision=rev, vendor_keyword=True)

    print(f"\nprocessing done : {log_file}\n\n\n\n\n\n")
# Out:
# ,---.                   ,--.  ,--.           ,--.     ,--.                      ,--.                       ,---.                  ,--.
# '   .-'  ,---. ,--.,--.,-'  '-.|  ,---.  ,---.|  ,---. `--' ,---.     ,-----.    |  |    ,---.  ,---.      /  O  \ ,--,--,  ,--,--.|  |,--. ,--.,-----. ,---. ,--.--.
# `.  `-. | .-. ||  ||  |'-.  .-'|  .-.  || .--'|  .-.  |,--.| .-. |    '-----'    |  |   | .-. || .-. |    |  .-.  ||      ' ,-.  ||  | \  '  / `-.  / | .-. :|  .--'
# .-'    |' '-' ''  ''  '  |  |  |  | |  |\ `--.|  | |  ||  || '-' '               |  '--.' '-' '' '-' '    |  | |  ||  ||  |\ '-'  ||  |  \   '   /  `-.\   --.|  |
# `-----'  `---'  `----'   `--'  `--' `--' `---'`--' `--'`--'|  |-'                `-----' `---' .`-  /     `--' `--'`--''--' `--`--'`--'.-'  /   `-----' `----'`--'
#                                                            `--'                                `---'                                   `---'                       JY™
# [  0.00%]  start dump parsing    -> save to ./log\20260209_175746 - act_dumpstate_vendor_parsing.txt
# [  0.00%]  start adc log         -> save to ./log\20260209_175746 - act_dumpstate_vendor_parsing_adc.txt
# [  0.00%]  start parsing comment -> save to ./log\20260209_175746 - act_dumpstate_vendor_comments.txt
# [  0.00%]  bootloader version : Kernel: Linux version 6.12.38-android16-5-pbde982d-abogkiA5760ZCU1AZAD-4k (kleaf@build-host) (Android (14043575, +pgo, +bolt, +lto, +mlgo, based on r536225) clang version 19.0.1 (https://android.googlesource.com/toolchain/llvm-project b3a530ec6537146650e42be89f1089e9a3588460), LLD 19.0.1) #1 SMP PREEMPT Fri Jan 30 08:59:06 UTC 2026
# [  0.00%]  bootloader version : Command line: console=ttynull stack_depot_disable=on cgroup_disable=pressure kasan.stacktrace=off kvm-arm.mode=protected bootconfig console=ram clk_ignore_unused clocksource=arch_sys_counter printk.devkmsg=on arm64.nomte rcupdate.rcu_expedited=1 swiotlb=noforce sgpu.lockup_timeout=5000 debug_non_panic_cpus memblock_memsize=procfs firmware_class.path=/vendor/firmware fw_devlink.strict=1 cpufreq.default_governor=energy_aware loop.max_part=7 ufs-exynos-core.async_probe=true sgpu.mcbp=0 fault_around_bytes=32768 kswapd_cpumask=0x7f kcompactd_cpumask=0x7f raise_min_free_kbytes=false disable_pcp_high_max cgroup.memory=nokmem,nosocket transparent_hugepage=never android_arch_task_struct_size=512 panic_on_warn=1 sec_debug_mode.force_upload=0x5 sec_debug_extra_info.rr_pwrsrc=0x0700000200 sec_debug_hw_param.dram_info=01,0A,00,8G sec_debug_reset_reason.pwrsrc=0x00000200 sec_debug_reset_reason.rstcnt_rs=0x000040000000 sec_debug_reset_reason.reset_reason=7 sec_reset.reset_reason=7 workqueue.panic_on_stall=2 console=ram loglevel=7 ignore_loglevel sec_debug.level=1 sec_audio_debug.debug_level=0x494d sec_debug.dump_sink=0x0 sec_debug.upload_count=0 gpt softdog.soft_margin=100 softdog.soft_panic=1 ess_setup=0xef000000 sec_debug_next=0x200000@0x91200000 sec-battery.misc_test=0x0 sec-battery.charging_mode=0x3000 s3cfb.bootloaderfb=0xf6200000 lcdtype=8388675 mcd-panel.boot_panel_id=8388675 exynos-drm.no_display=0 mcd-panel.board_rev=7 consoleblank=0 ehci_hcd.park=3 oops=panic sec-battery.fgsrc_vbat=0 sm5714b-charger.fgsrc_vbat=0 sm5714b-fuelgauge.fgsrc_vbat=0 common_muic.muic_param_pmic_info=11 common_muic.muic_param_pdic_info=1 common_muic.muic_param_afc_mode=0x30 pdic_notifier_module.pdic_param_lpcharge=0 sales_code=CHC sec-battery.sales_code=CHC sec_debug.bin=N snd_soc_core.pmdown_time=1000 cpif.cp_btl=on usb_notify_layer.usb_restrict=0 kg_drv.fuse_bit=00 kg_drv.ap_serial=BBBB000000000000000011748E5DB713 kg_drv.enable=0 hdm.status=NONE sec_bootstat.boot_time_bl1=100 sec_bootstat.boot_time_bl2=941 sec_bootstat.boot_time_bl3=2184 bootconfig
# [  0.00%]  bootloader version : androidboot.bootloader = "A5760ZCU1AZAD"
# [  0.00%]  bootloader version : androidboot.bootloader = "A5760ZCU1AZAD"
# [ 20.20%]  Kernel version : [ro.boot.bootloader]: [A5760ZCU1AZAD]
# [ 20.21%]  Kernel version : [ro.bootloader]: [A5760ZCU1AZAD]
# [ 21.19%]  LAST KMSG : ------ LAST KMSG (/proc/last_kmsg) ------
# [ 22.19%]  Kernel version : [0:    1.818260] [BRST] init_debug_bootloader_reset_logs: magic = b0071257 / version = 20230221 / total sz = 64200 / MAX = 800
# [ 22.19%]  Kernel version : [0:    1.818268] [BRST] init_debug_bootloader_reset_logs: struct size: 1b8 / block size: 200
# [ 22.19%]  Kernel version : [0:    1.822548] [BRST] init_debug_bootloader_reset_logs: bore_cnt = 139
# [ 22.21%]  Kernel version : [0:    2.153730] set_bootloader_active_slot: Set Bootloader Active Slot to A!
# [ 22.25%]  Kernel version : [0:    1.824638] [BRST] init_debug_bootloader_reset_logs: magic = b0071257 / version = 20230221 / total sz = 64200 / MAX = 800
# [ 22.25%]  Kernel version : [0:    1.824645] [BRST] init_debug_bootloader_reset_logs: struct size: 1b8 / block size: 200
# [ 22.25%]  Kernel version : [0:    1.827543] [BRST] init_debug_bootloader_reset_logs: bore_cnt = 140
# [ 22.29%]  Kernel version : [0:    2.854783] [BLDP] bootloader_mode = 0
# [ 22.29%]  Kernel version : [0:    2.854791] [BLDP] bootloader_event_target[] =
# [ 22.29%]  Kernel version : [0:    2.854794] [BLDP] bootloader_event = 0x0
# [ 22.29%]  Kernel version : [0:    2.854797] [BLDP] bootloader_rp = 0x1
# [ 22.29%]  LAST KMSG : ------ 0.009s was the duration of 'LAST KMSG' ------
# [ 31.05%]  Kernel version :         "name": "RELEASE_BOOTLOADER_DETERMINISTIC_AVB_SALT",
# [ 31.05%]  Kernel version :         "description": "If true, a deterministic salt will be used in the avb signed bootloader.img partitions.",
# [ 31.39%]  Kernel version :         "name": "RELEASE_BOOTLOADER_DETERMINISTIC_AVB_SALT",
# [ 31.39%]  Kernel version :         "description": "If true, a deterministic salt will be used in the avb signed bootloader.img partitions.",
# [ 31.64%]  Kernel version :         "name": "RELEASE_BOOTLOADER_DETERMINISTIC_AVB_SALT",
# [ 31.64%]  Kernel version :         "description": "If true, a deterministic salt will be used in the avb signed bootloader.img partitions.",
# [ 42.73%]  Kernel version : 0x0000000000000000-0x0000000000000000 0x00004000 (      16 KB ) nomap unusable log_bootloader_itmon
# [100.00%] finish dump and adc parsing, clear the parameters
#
# processing done : act_dumpstate.txt

# %%
"health_status".lower() in "[  881.230727] [7:  kworker/u32:6:  205] sc_charger_timer_work: health_status=24 chg_status=3".lower()

# %%
# First install: pip install tqdm
from tqdm import tqdm
import time

for i in tqdm(range(100), desc="Loading", unit="%"):
    time.sleep(0.05)  # Simulate work

# %%
import time
import sys

def animated_progress(total=100, width=50):
    for i in range(total + 1):
        # Calculate progress
        percentage = i
        filled = int(width * i // total)
        bar = '█' * filled + '░' * (width - filled)
        
        # Print on same line
        sys.stdout.write(f'\r|{bar}| {percentage:3d}%')
        sys.stdout.flush()
        time.sleep(0.05)
    
    print()  # New line after completion

animated_progress()
