# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc85853 import project

from time import sleep as delay
from interface.cui_logger import logger as log

if "ic" in globals():
    ic.close()

# ic = project(device="sc85853", revision="0p0", emulator="cp2112", logging=False, is_gui=False)
ic = project(device="sc85853", revision="0p0", emulator="ch341", logging=False, is_gui=False)
# Out:
# initialized with i2c address 0x6e by default

# %%
ic.i2c_scan()
# Out:
# acked address list : [101]
# update i2c address : 0x6e --> 0x65
# [101]

# %%
ic.status
# Out:
# Addr    Reg           Value    Bit7                 Bit6                 Bit5                  Bit4                  Bit3                   Bit2                      Bit1                 Bit0
# ------  ------------  -------  -------------------  -------------------  --------------------  --------------------  ---------------------  ------------------------  -------------------  ---------------------
# 0x01    INT_DEVICE0   0x46     POR_FLAG             CP_SWITCHING_FLAG    VIN_IN_PRESENT_FLAG   VB_OUT_PRESENT_FLAG   VIN_IN_TH_CHG_EN_FLAG  VB_OUT_IN_TH_CHG_EN_FLAG  RSVD                 RSVD
# 0x02    INT_DEVICE1   0xff     RSVD                 VEXT_INSERT_FLAG     VUSB_INSERT_FLAG      VEXT_REMOVE_FLAG      VUSB_REMOVE_FLAG       VOUT_TH_CHG_EN_FLAG       VOUT_TH_REV_EN_FLAG  VOUT_INSERT_FLAG
# 0x03    INT_DEVICE2   0xff     RSVD                 RSVD                 QB2_ON_FLAG           QB1_ON_FLAG           VEXT_DRV_ON_FLAG       VEXT_OVP_FLAG             VUSB_DRV_ON_FLAG     VUSB_OVP_FLAG
# 0x04    INT_DEVICE3   0xff     IIN_REG_ACTIVE_FLAG  RSVD                 VBAT_REG_ACTIVE_FLAG  TDIE_REG_ACTIVE_FLAG  TDIE_REG_EXIT_FLAG     IIN_UCP_RISE_FLAG         WD_TIMEOUT_FLAG      ADC_DONE_FLAG
# 0x05    INT_FAULT0    0x00     VBAT_OVP_FLAG        VOUT_OVP_FLAG        RSVD                  RSVD                  VB_OUT_OVP_FLAG        VIN_OVP_FLAG              IIN_UCP_FALL_FLAG    IIN_OCP_FLAG
# 0x06    INT_FAULT1    0x50     C2B_OPEN_FLAG        C2A_OPEN_FLAG        C1B_OPEN_FLAG         C1A_OPEN_FLAG         C2B_SHORT_FLAG         C2A_SHORT_FLAG            C1B_SHORT_FLAG       C1A_SHORT_FLAG
# 0x07    INT_FAULT2    0xff     PMID_ERRORLO_FLAG    PMID_ERRORHI_FLAG    RSVD                  RSVD                  RSVD                   RSVD                      RSVD                 PIN_DIAG_FAIL_FLAG
# 0x08    INT_FAULT3    0x0d     BST2_OPEN_FLAG       BST1B_OPEN_FLAG      BST1A_OPEN_FLAG       BST3B_SHORT_FLAG      BST3A_SHORT_FLAG       BST2_SHORT_FLAG           BST1B_SHORT_FLAG     BST1A_SHORT_FLAG
# 0x09    INT_FAULT4    0xff     EXT2_FET_OPEN_FLAG   EXT2_DRV_SHORT_FLAG  EXT1_FET_OPEN_FLAG    EXT1_DRV_SHORT_FLAG   RSVD                   RSVD                      BST3B_OPEN_FLAG      BST3A_OPEN_FLAG
# 0x0a    INT_FAULT5    0x00     Q3B_SHORT_FLAG       Q3A_SHORT_FLAG       C1PA_C1PB_SHORT_FLAG  Q5_SHORT_FLAG         C2B_SHORT_PH3_FLAG     C2A_SHORT_PH3_FLAG        C1B_SHORT_PH3_FLAG   C1A_SHORT_PH3_FLAG
# 0x0b    INT_FAULT6    0xc8     SS_TIMEOUT_FLAG      SS_FAIL_FLAG         TSHUT_FLAG            NTC_FLT_FLAG          C1P2OUT_OVP_FLAG       C1P2OUT_UVP_FLAG          VO12OUT_UVP_FLAG     CONV_OCP_FLAG
# 0x14    STAT_DEVICE0  0x00     VB_OUT_PRESENT_STAT  CP_SWITCHING_STAT    VIN_PRESENT_STAT      VOUT_INSERT_STAT      VOUT_TH_REV_EN_STAT    VOUT_TH_CHG_EN_STAT       VIN_TH_CHG_EN_STAT   VB_OUT_TH_CHG_EN_STAT
# 0x15    STAT_DEVICE1  0x03     VEXT_OVP_STAT        VEXT_DRV_ON_STAT     VUSB_INSERT_STAT      VEXT_INSERT_STAT      VUSB_OVP_STAT          VUSB_DRV_ON_STAT          QB1_ON_STAT          QB2_ON_STAT
# 0x16    STAT_DEVICE2  0x00     ADC_DONE_STAT        WD_TIMEOUT_STAT      IIN_UCP_RISE_STAT     VOUT_OK_SW_AVDD_STAT  TDIE_REG_ACTIVE_STAT   VBAT_REG_ACTIVE_STAT      RSVD                 IIN_REG_ACTIVE_STAT
# 0x17    STAT_FAULT0   0x00     VBAT_OVP_STAT        VOUT_OVP_STAT        RSVD                  RSVD                  VB_OUT_OVP_STAT        VIN_OVP_STAT              IIN_UCP_FALL_STAT    IIN_OCP_STAT
# 0x18    STAT_FAULT1   0x00     C2B_OPEN_STAT        C2A_OPEN_STAT        C1B_OPEN_STAT         C1A_OPEN_STAT         C2B_SHORT_STAT         C2A_SHORT_STAT            C1B_SHORT_STAT       C1A_SHORT_STAT
# 0x19    STAT_FAULT2   0x00     PMID_ERRORLO_STAT    PMID_ERRORHI_STAT    RSVD                  RSVD                  RSVD                   RSVD                      PMID_ERRORHI_STAT    PMID_ERRORLO_STAT
# 0x1a    STAT_FAULT3   0x00     BST2_OPEN_STAT       BST1B_OPEN_STAT      BST1A_OPEN_STAT       BST3B_SHORT_STAT      BST3A_SHORT_STAT       BST2_SHORT_STAT           BST1B_SHORT_STAT     BST1A_SHORT_STAT
# 0x1b    STAT_FAULT4   0x00     BST3B_OPEN_STAT      BST3A_OPEN_STAT      RSVD                  RSVD                  EXT1_DRV_SHORT_STAT    EXT1_FET_OPEN_STAT        EXT2_DRV_SHORT_STAT  EXT2_FET_OPEN_STAT
# 0x1c    STAT_FAULT5   0x00     Q3B_SHORT_STAT       Q3A_SHORT_STAT       C1PA_C1PB_SHORT_STAT  Q5_SHORT_STAT         C2B_SHORT_PH3_STAT     C2A_SHORT_PH3_STAT        C1B_SHORT_PH3_STAT   C1A_SHORT_PH3_STAT
# 0x1d    STAT_FAULT6   0x00     SS_TIMEOUT_STAT      SS_FAIL_STAT         TSHUT_STAT            NTC_FLT_STAT          C1P2OUT_OVP_STAT       C1P2OUT_UVP_STAT          VO12OUT_UVP_STAT     CONV_OCP_STAT

# %%
ic.status
# Out:
# Addr    Reg           Value    Bit7                 Bit6                 Bit5                  Bit4                  Bit3                   Bit2                      Bit1                 Bit0
# ------  ------------  -------  -------------------  -------------------  --------------------  --------------------  ---------------------  ------------------------  -------------------  -------------------
# 0x01    INT_DEVICE0   0x00     POR_FLAG             CP_SWITCHING_FLAG    VIN_IN_PRESENT_FLAG   VB_OUT_PRESENT_FLAG   VIN_IN_TH_CHG_EN_FLAG  VB_OUT_IN_TH_CHG_EN_FLAG  RSVD                 RSVD
# 0x02    INT_DEVICE1   0x00     RSVD                 VEXT_INSERT_FLAG     VUSB_INSERT_FLAG      VEXT_REMOVE_FLAG      VUSB_REMOVE_FLAG       VOUT_TH_CHG_EN_FLAG       VOUT_TH_REV_EN_FLAG  VOUT_INSERT_FLAG
# 0x03    INT_DEVICE2   0x00     RSVD                 RSVD                 QB2_ON_FLAG           QB1_ON_FLAG           VEXT_DRV_ON_FLAG       VEXT_OVP_FLAG             VUSB_DRV_ON_FLAG     VUSB_OVP_FLAG
# 0x04    INT_DEVICE3   0x00     IIN_REG_ACTIVE_FLAG  RSVD                 VBAT_REG_ACTIVE_FLAG  TDIE_REG_ACTIVE_FLAG  TDIE_REG_EXIT_FLAG     IIN_UCP_RISE_FLAG         WD_TIMEOUT_FLAG      ADC_DONE_FLAG
# 0x05    INT_FAULT0    0x00     VBAT_OVP_FLAG        VOUT_OVP_FLAG        RSVD                  RSVD                  VB_OUT_OVP_FLAG        VIN_OVP_FLAG              IIN_UCP_FALL_FLAG    IIN_OCP_FLAG
# 0x06    INT_FAULT1    0x00     C2B_OPEN_FLAG        C2A_OPEN_FLAG        C1B_OPEN_FLAG         C1A_OPEN_FLAG         C2B_SHORT_FLAG         C2A_SHORT_FLAG            C1B_SHORT_FLAG       C1A_SHORT_FLAG
# 0x07    INT_FAULT2    0x00     PMID_ERRORLO_FLAG    PMID_ERRORHI_FLAG    RSVD                  RSVD                  RSVD                   RSVD                      RSVD                 PIN_DIAG_FAIL_FLAG
# 0x08    INT_FAULT3    0x00     BST2_OPEN_FLAG       BST1B_OPEN_FLAG      BST1A_OPEN_FLAG       BST3B_SHORT_FLAG      BST3A_SHORT_FLAG       BST2_SHORT_FLAG           BST1B_SHORT_FLAG     BST1A_SHORT_FLAG
# 0x09    INT_FAULT4    0x00     EXT2_FET_OPEN_FLAG   EXT2_DRV_SHORT_FLAG  EXT1_FET_OPEN_FLAG    EXT1_DRV_SHORT_FLAG   RSVD                   RSVD                      BST3B_OPEN_FLAG      BST3A_OPEN_FLAG
# 0x0a    INT_FAULT5    0x00     Q3B_SHORT_FLAG       Q3A_SHORT_FLAG       C1PA_C1PB_SHORT_FLAG  Q5_SHORT_FLAG         C2B_SHORT_PH3_FLAG     C2A_SHORT_PH3_FLAG        C1B_SHORT_PH3_FLAG   C1A_SHORT_PH3_FLAG
# 0x0b    INT_FAULT6    0x00     SS_TIMEOUT_FLAG      SS_FAIL_FLAG         TSHUT_FLAG            NTC_FLT_FLAG          C1P2OUT_OVP_FLAG       C1P2OUT_UVP_FLAG          VO12OUT_UVP_FLAG     CONV_OCP_FLAG
# 0x0c    MASK_DEVICE0  0x00     POR_MASK             CP_SWITCHING_MASK    VIN_IN_PRESENT_MASK   VB_OUT_PRESENT_MASK   VIN_TH_CHG_EN_MASK     VB_OUT_TH_CHG_EN_MASK     RSVD                 RSVD
# 0x0d    MASK_DEVICE1  0x00     VOUT_INSERT_MASK     VOUT_TH_REV_EN_MASK  VOUT_TH_CHG_EN_MASK   VUSB_REMOVE_MASK      VEXT_REMOVE_MASK       VUSB_INSERT_MASK          VEXT_INSERT_MASK     RSVD
# 0x0e    MASK_DEVICE2  0x00     VUSB_OVP_MASK        VUSB_DRV_ON_MASK     VEXT_OVP_MASK         VEXT_DRV_ON_MASK      QB1_ON_MASK            QB2_ON_MASK               RSVD                 RSVD
# 0x0f    MASK_DEVICE3  0x00     ADC_DONE_MASK        WD_TIMEOUT_MASK      IIN_UCP_RISE_MASK     TDIE_REG_EXIT_MASK    TDIE_REG_ACTIVE_MASK   VBAT_REG_ACTIVE_MASK      RSVD                 IIN_REG_ACTIVE_MASK
# 0x10    MASK_FAULT0   0x00     VBAT_OVP_MASK        VOUT_OVP_MASK        RSVD                  RSVD                  VB_OUT_OVP_MASK        VIN_OVP_MASK              IIN_UCP_FALL_MASK    IIN_OCP_MASK
# 0x11    MASK_FAULT1   0x00     PIN_DIAG_FAIL_MASK   CFLY_OPEN_MASK       CFLY_SHORT_MASK       BST_FAIL_MASK         RSVD                   RSVD                      PMID_ERRORHI_MASK    PMID_ERRORLO_MASK
# 0x12    MASK_FAULT2   0x00     RSVD                 RSVD                 RSVD                  RSVD                  EXT_DRV1_SHORT_MASK    EXT_FET1_OPEN_MASK        EXT_DRV2_SHORT_MASK  EXT_FET2_OPEN_MASK
