# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc85853 import project

from time import sleep as delay
from interface.cui_logger import logger as log

if "ic" in globals():
    ic.close()

ic = project(device="sc85853", revision="0p0", emulator="cp2112", logging=False, is_gui=False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 11
#       8 if "ic" in globals():
#       9     ic.close()
# ---> 11 ic = project(device="sc85853", revision="0p0", emulator="cp2112", logging=False, is_gui=False)
#
# File c:\Lab_Experiement\south_lab\project\sc85853\sc85853_0p0.py:69, in project.__init__(self, **kwargs)
#      66 reg_map  = get_map(device=self.device, revision=self.revision)
#      67 i2c_info = get_i2c_info(device=self.device)
# ---> 69 i2c = allcoation.bridge_allcoation(emulator=emulator, logging=is_logging)
#      71 super().__init__(regmap=reg_map, i2c_info=i2c_info, i2c_h=i2c, device=self.device, logging=is_logging, is_gui=is_logging)
#      72 function.__init__(self, obj=self)
#
# File c:\Lab_Experiement\south_lab\interface\cui_i2c.py:34, in allcoation.bridge_allcoation(emulator, logging)
#      32 elif "cp2112" in emulator:
#      33     from interface.i2c_bridge.cp2112 import cp2112
# ---> 34     i2c = cp2112(retry=1, logging=logging, led=True)
#      36 return i2c
#
# File c:\Lab_Experiement\south_lab\interface\i2c_bridge\cp2112.py:78, in cp2112.__init__(self, retry, logging, led)
#      75             pid = dev["product_id"]
#      77 # self.h.open_path(hid.enumerate(parameter.vendor_id, parameter.product_id)[0]["path"])
# ---> 78 self.h.open_path(hid.enumerate(vid, pid)[0]["path"])
#      79 log_wrapping("cp2112", f"initiate the device on hid", self.logging)
#      81 # self.hid_send([0x03, 0xFF, 0x00, 0x00, 0x00]) # set gpio to open drain
#
# UnboundLocalError: cannot access local variable 'vid' where it is not associated with a value

# %%
ic.status
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ic.status
#
# NameError: name 'ic' is not defined
