# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc85853 import project

from time import sleep as delay
from interface.cui_logger import logger as log

if "ic" in globals():
    ic.close()

ic = project(device="sc85853", revision="0p0", emulator="cp2112", logging=False, is_gui=False)
# ic = project(device="sc85853", revision="0p0", emulator="ch341", logging=False, is_gui=False)
# Out:
# cleanup the class object
# cleanup the class object
# initialized with i2c address 0x6e by default

# %%
log.scan_visa()
# Out:
# ['USB0::0x05E6::0x6500::04681071::INSTR',
#  'USB0::0x0957::0x0F07::MY47000200::INSTR',
#  'USB0::0x0699::0x052C::SGVJ0003246::INSTR',
#  'ASRL14::INSTR',
#  'ASRL15::INSTR']

# %%
ic.status
# Out:
# Addr    Reg           Value    Bit7                 Bit6                 Bit5                 Bit4                  Bit3                   Bit2                      Bit1                 Bit0
# ------  ------------  -------  -------------------  -------------------  -------------------  --------------------  ---------------------  ------------------------  -------------------  ---------------------
# 0x01    INT_DEVICE0   0x00     POR_FLAG             CP_SWITCHING_FLAG    VIN_IN_PRESENT_FLAG  VB_OUT_PRESENT_FLAG   VIN_IN_TH_CHG_EN_FLAG  VB_OUT_IN_TH_CHG_EN_FLAG  RSVD                 RSVD
# 0x02    INT_DEVICE1   0x00     VOUT_INSERT_FLAG     VOUT_TH_REV_EN_FLAG  VOUT_TH_CHG_EN_FLAG  VUSB_REMOVE_FLAG      VEXT_REMOVE_FLAG       VUSB_INSERT_FLAG          VEXT_INSERT_FLAG     RSVD
# 0x03    INT_DEVICE2   0x00     VUSB_OVP_FLAG        VUSB_DRV_ON_FLAG     VEXT_OVP_FLAG        VEXT_DRV_ON_FLAG      QB1_ON_FLAG            QB2_ON_FLAG               RSVD                 RSVD
# 0x04    INT_DEVICE3   0x00     ADC_DONE_FLAG        WD_TIMEOUT_FLAG      IIN_UCP_RISE_FLAG    TDIE_REG_EXIT_FLAG    TDIE_REG_ACTIVE_FLAG   VBAT_REG_ACTIVE_FLAG      RSVD                 IIN_REG_ACTIVE_FLAG
# 0x05    INT_FAULT0    0x00     IIN_OCP_FLAG         IIN_UCP_FALL_FLAG    VIN_OVP_FLAG         VB_OUT_OVP_FLAG       RSVD                   RSVD                      VOUT_OVP_FLAG        VBAT_OVP_FLAG
# 0x06    INT_FAULT1    0x00     C1A_SHORT_FLAG       C1B_SHORT_FLAG       C2A_SHORT_FLAG       C2B_SHORT_FLAG        C1A_OPEN_FLAG          C1B_OPEN_FLAG             C2A_OPEN_FLAG        C2B_OPEN_FLAG
# 0x07    INT_FAULT2    0x00     PIN_DIAG_FAIL_FLAG   RSVD                 RSVD                 RSVD                  RSVD                   RSVD                      PMID_ERRORHI_FLAG    PMID_ERRORLO_FLAG
# 0x08    INT_FAULT3    0x00     BST1A_SHORT_FLAG     BST1B_SHORT_FLAG     BST2_SHORT_FLAG      BST3A_SHORT_FLAG      BST3B_SHORT_FLAG       BST1A_OPEN_FLAG           BST1B_OPEN_FLAG      BST2_OPEN_FLAG
# 0x09    INT_FAULT4    0x00     BST3A_OPEN_FLAG      BST3B_OPEN_FLAG      RSVD                 RSVD                  EXT1_DRV_SHORT_FLAG    EXT1_FET_OPEN_FLAG        EXT2_DRV_SHORT_FLAG  EXT2_FET_OPEN_FLAG
# 0x0a    INT_FAULT5    0x00     C1A_SHORT_PH3_FLAG   C1B_SHORT_PH3_FLAG   C2A_SHORT_PH3_FLAG   C2B_SHORT_PH3_FLAG    Q5_SHORT_FLAG          C1PA_C1PB_SHORT_FLAG      Q3A_SHORT_FLAG       Q3B_SHORT_FLAG
# 0x0b    INT_FAULT6    0x00     CONV_OCP_FLAG        VO12OUT_UVP_FLAG     C1P2OUT_UVP_FLAG     C1P2OUT_OVP_FLAG      NTC_FLT_FLAG           TSHUT_FLAG                SS_FAIL_FLAG         SS_TIMEOUT_FLAG
# 0x14    STAT_DEVICE0  0x10     VB_OUT_PRESENT_STAT  CP_SWITCHING_STAT    VIN_PRESENT_STAT     VOUT_INSERT_STAT      VOUT_TH_REV_EN_STAT    VOUT_TH_CHG_EN_STAT       VIN_TH_CHG_EN_STAT   VB_OUT_TH_CHG_EN_STAT
# 0x15    STAT_DEVICE1  0x00     VEXT_OVP_STAT        VEXT_DRV_ON_STAT     VUSB_INSERT_STAT     VEXT_INSERT_STAT      VUSB_OVP_STAT          VUSB_DRV_ON_STAT          QB1_ON_STAT          QB2_ON_STAT
# 0x16    STAT_DEVICE2  0x00     ADC_DONE_STAT        WD_TIMEOUT_STAT      IIN_UCP_RISE_STAT    VOUT_OK_SW_AVDD_STAT  TDIE_REG_ACTIVE_STAT   VBAT_REG_ACTIVE_STAT      RSVD                 IIN_REG_ACTIVE_STAT
# 0x17    STAT_FAULT0   0x00     IIN_OCP_STAT         IIN_UCP_FALL_STAT    RSVD                 RSVD                  VIN_OVP_STAT           VB_OUT_OVP_STAT           VOUT_OVP_STAT        VBAT_OVP_STAT
# 0x18    STAT_FAULT1   0x00     C1A_SHORT_STAT       C1B_SHORT_STAT       C2A_SHORT_STAT       C2B_SHORT_STAT        C1A_OPEN_STAT          C1B_OPEN_STAT             C2A_OPEN_STAT        C2B_OPEN_STAT
# 0x19    STAT_FAULT2   0x00     PIN_DIAG_FAIL_STAT   RSVD                 RSVD                 RSVD                  RSVD                   RSVD                      PMID_ERRORHI_STAT    PMID_ERRORLO_STAT
# 0x1a    STAT_FAULT3   0x00     BST1A_SHORT_STAT     BST1B_SHORT_STAT     BST2_SHORT_STAT      BST3A_SHORT_STAT      BST3B_SHORT_STAT       BST1A_OPEN_STAT           BST1B_OPEN_STAT      BST2_OPEN_STAT
# 0x1b    STAT_FAULT4   0x00     BST3A_OPEN_STAT      BST3B_OPEN_STAT      RSVD                 RSVD                  EXT1_DRV_SHORT_STAT    EXT1_FET_OPEN_STAT        EXT2_DRV_SHORT_STAT  EXT2_FET_OPEN_STAT
# 0x1c    STAT_FAULT5   0x00     C1A_SHORT_PH3_STAT   C1B_SHORT_PH3_STAT   C2A_SHORT_PH3_STAT   C2B_SHORT_PH3_STAT    Q5_SHORT_STAT          C1PA_C1PB_SHORT_STAT      Q3A_SHORT_STAT       Q3B_SHORT_STAT
# 0x1d    STAT_FAULT6   0x00     CONV_OCP_STAT        VO12OUT_UVP_STAT     C1P2OUT_UVP_STAT     C1P2OUT_OVP_STAT      NTC_FLT_STAT           TSHUT_STAT                SS_FAIL_STAT         SS_TIMEOUT_STAT

# %%
ic.ADC_EN = 1
ic.ADC_RATE = 0
ic.VBAT_ADC*.00125
# Out:
# 4.00125

# %%
ic.status_adc
# Out:
# ADC         Hex    LSB         Value
# ----------  -----  ----------  -------
# IIN_ADC     0x000  0.001875 A  0 A
# VIN_ADC     0x000  0.00625 V   0 V
# VB_OUT_ADC  0x000  0.00625 V   0 V
# VUSB_ADC    0x000  0.00625 V   0 V
# VEXT_ADC    0x000  0.00625 V   0 V
# VOUT_ADC    0x000  0.00125 V   0 V
# VBAT_ADC    0x000  0.00125 V   0 V
# C1P_ADC     0x000  0.00625 V   0 V
# NTC_ADC     0x000  0.01465 %   0 %
# TDIE_ADC    0x000  0.5 C       0 C

# %%
ic.VEXT_OVP = 7
ic.VEXT_SW_CTRL1 = 0
ic.VEXT_OFF_GATE_CTRL = 0
ic.C1P2OUT_UVP=2
ic.VUSB_OVP = 7
ic.VUSB_SW_CTRL1 = 1
ic.NTC_FLT
ic.NTC_FLT_DIS = 1
ic.NTC_ADC_DIS = 1
ic.VBAT_REG_DIS = 1
ic.IIN_REG_DIS = 1
print(ic.NTC_FLT_DIS)
ic.STANDBY_MODE_SET = 1
ic.QB1_CTRL2 = 1
ic.CP_EN=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ic.VEXT_OVP = 7
#       2 ic.VEXT_SW_CTRL1 = 0
#       3 ic.VEXT_OFF_GATE_CTRL = 0
#
# File c:\Lab_Experiement\south_lab\interface\cui_main.py:553, in cui_frame.__setattr__(self, name, value)
#     551 if cache.initialized:
#     552     if name in cache.reg_map.keys():
# --> 553         self._write(name, value)
#     554     else:
#     555         super().__setattr__(name, value)
#
# File c:\Lab_Experiement\south_lab\interface\cui_main.py:466, in cui_frame._write(self, name, value)
#     464 # clear the taget bits between msb and lsb
#     465 mask        = ~(((1 << (msb_index - lsb_index + 1)) -1) << lsb_index)
# --> 466 masked_data = readbyte & mask
#     467 new_data    = masked_data | (split_data << lsb_index)
#     469 i2c_h.i2c_write(i2c_a, reg_address, new_data)
#
# TypeError: unsupported operand type(s) for &: 'NoneType' and 'int'

# %%
ic.IIN_REG*0.0375
# Out:
# 1.125

# %%
ds.horizontal_scale = 200E-3
ds.horizontal_position = 0
ds.ch1.vertical_offset = 0
ds.ch2.vertical_offset = 0
ds.ch3.vertical_offset = 0
ds.ch4.vertical_offset = 0

ds.ch1.vertical_grid = -3
ds.ch2.vertical_grid = -3
ds.ch3.vertical_grid = -3
ds.ch4.vertical_grid = -3

# %%
ds.ch1.label = "PMID"
ds.ch2.label = "BST1A"
ds.ch3.label = "BST2"
ds.ch4.label = "BST3A"

# %%
now = datetime.datetime.now()
timenow = now.strftime("%Y-%m-%d %H%M%S")
print(timenow)

file_name_waveform = f'{timenow} - TABS12Ultra - After Rework BST FAIL_2'
ds.save_waveform = file_name_waveform

# %%
# Out:
# IIN_UCP_DIS = 1
# NTC_FLT_DIS = 1
# VBAT_OVP_DIS = 1
# STANDBY_MODE_SET = 1
# VUSB_SHUTDOWN_SET = 0
# SS_TIMEOUT = 0

# %%
ic.QB1_CTRL2 =1
ic.CP_EN = 1

# %%
ic.qb1_enable_charging
# Out:
# STANDBY_MODE_SET = 1
# QB1_CTRL2 = 1
# CP_EN = 0

# %%
ic.VUSB_SW_CTRL1 = 1
ic.VUSB_SW_CTRL2 = 1

# %%
ic.VUSB_OVP = 7
