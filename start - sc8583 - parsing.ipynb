# %% [markdown]
# # I2C device initialization

# %%
from project.sc8583 import project

if "ic" in globals():
    ic.close()
    print(f"destroy the object")
    
ic = project(device="sc8583", revision="1p1", emulator="ch341", logging=False, is_gui=False)
# Out:
# [sc8583 __init__] initialized with i2c address 0x6e by default

# %% [markdown]
# # log analysis

# %%
file = "./log/dump.txt"
ic.step_1_matching(dump=file, vendor_keyword=True)

# %%
file = "./log/fail.txt"
ic.step_1_matching(dump=file, vendor_keyword=True)

# %%
for n1 in [1,2]:
    ic.step_1_matching(dump=f"./log/dump{n1}-{n2}.txt", vendor_keyword=False)

# %% [markdown]
# # add the custom keyword method
# # args would be good

# %%
temp = ["Line 10473: [  102.726857] [2:  kworker/u32:8: 1092] sc_charger_check_vbatmin: iin_adc:1875 vbat_adc:3788000 vbus_adc:9093750 vbus_wpc_adc:12500 vbat_dcic_adc:3765000",
"Line 10483: [  102.758833] [4:  kworker/u32:0:   12] sc_charger_monitor_work: state(CHECK_VBAT), iin_cc(0mA), v_float(4485mV), vbat(3761000uV), vin(9093750uV), iin(1875uA), die_temp(245), vbat_dcic(3776250), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(0/0mV/0mA)",
"Line 10703: [  102.854991] [4:  kworker/u32:8: 1092] sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3761000 vbus_adc:9087500 vbus_wpc_adc:12500 vbat_dcic_adc:3771250",
"Line 10899: [  102.931146] [1:  kworker/u32:8: 1092] sc_charger_calculate_voltage: vbat=3761mV vbat_dcic=3791mV vbat_diff=30mV",
"Line 11238: [  103.428247] [3:  kworker/u32:1:   13] sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3786000 vbus_adc:16725000 vbus_wpc_adc:12500 vbat_dcic_adc:3778750",
"Line 11438: [  103.978316] [0:  kworker/u32:1:   13] sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3786000 vbus_adc:16725000 vbus_wpc_adc:12500 vbat_dcic_adc:3778750",
"Line 11640: [  104.098456] [5:  kworker/u32:1:   13] sc_charger_start_direct_charging: iin_adc:1530000 vbat_adc:3796000 vbus_adc:16437500 vbus_wpc_adc:6250 vbat_dcic_adc:3947500",
"Line 11835: [  104.175072] [4:  kworker/u32:1:   13] sc_charger_calculate_voltage: vbat=3801mV vbat_dcic=3802mV vbat_diff=1mV",
"Line 11981: [  104.613595] [0:  kworker/u32:8: 1092] sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3798000 vbus_adc:12575000 vbus_wpc_adc:12500 vbat_dcic_adc:3802500",
"Line 12276: [  105.165454] [4:  kworker/u32:8: 1092] sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3798000 vbus_adc:12575000 vbus_wpc_adc:12500 vbat_dcic_adc:3802500",
"Line 12617: [  105.763334] [0:  kworker/u32:0:   12] sc_charger_check_dcmode_status: iin:1627500 iin_target:3000000 vbat:3919000 vbat_target:4190000 power_uw:20174800 vbus:12206250 vbus_wpc:6250 vbat_dcic:3923750 vbat_reg:0",
"Line 12746: [  106.243322] [0:  kworker/u32:8: 1092] sc_charger_check_dcmode_status: iin:2000625 iin_target:3000000 vbat:3941000 vbat_target:4190000 power_uw:25280000 vbus:12381250 vbus_wpc:6250 vbat_dcic:3950000 vbat_reg:0",
"Line 12886: [  106.771491] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:2336250 iin_target:3000000 vbat:3974000 vbat_target:4190000 power_uw:30087680 vbus:12556250 vbus_wpc:12500 vbat_dcic:3977500 vbat_reg:0",
"Line 13026: [  107.235512] [0:  kworker/u32:0:   12] sc_charger_check_dcmode_status: iin:2681250 iin_target:3000000 vbat:3998000 vbat_target:4190000 power_uw:35174720 vbus:12731250 vbus_wpc:6250 vbat_dcic:4003750 vbat_reg:0",
"Line 13156: [  107.715785] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:3046875 iin_target:3000000 vbat:4026000 vbat_target:4190000 power_uw:40694560 vbus:12906250 vbus_wpc:0 vbat_dcic:4030000 vbat_reg:0",
"Line 13284: [  108.199786] [0:  kworker/u32:8: 1092] sc_charger_check_dcmode_status: iin:3005625 iin_target:3000000 vbat:4027000 vbat_target:4190000 power_uw:40086700 vbus:12900000 vbus_wpc:6250 vbat_dcic:4030000 vbat_reg:0",
"Line 13419: [  108.675594] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:2953125 iin_target:3000000 vbat:4025000 vbat_target:4190000 power_uw:39333960 vbus:12887500 vbus_wpc:6250 vbat_dcic:4030000 vbat_reg:0",
"Line 13548: [  109.123563] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:2945625 iin_target:3000000 vbat:4028000 vbat_target:4190000 power_uw:39227400 vbus:12893750 vbus_wpc:6250 vbat_dcic:4031250 vbat_reg:0",
"Line 13671: [  109.599899] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:2934375 iin_target:3000000 vbat:4030000 vbat_target:4190000 power_uw:39080880 vbus:12887500 vbus_wpc:6250 vbat_dcic:4033750 vbat_reg:0",
"Line 13798: [  110.095289] [0:  kworker/u32:8: 1092] sc_charger_check_dcmode_status: iin:2968125 iin_target:3000000 vbat:4032000 vbat_target:4190000 power_uw:39593120 vbus:12912500 vbus_wpc:12500 vbat_dcic:4037500 vbat_reg:0",
"Line 14079: [  111.431251] [4:  kworker/u32:8: 1092] sc_charger_start_direct_charging: iin_adc:2951250 vbat_adc:4038000 vbus_adc:12912500 vbus_wpc_adc:12500 vbat_dcic_adc:4040000",
"Line 14276: [  111.507295] [4:  kworker/u32:8: 1092] sc_charger_calculate_voltage: vbat=3832mV vbat_dcic=3835mV vbat_diff=3mV",
"Line 14513: [  111.647217] [1:  kworker/u32:8: 1092] sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3832000 vbus_adc:13475000 vbus_wpc_adc:12500 vbat_dcic_adc:3835000",
"Line 14708: [  111.723367] [1:  kworker/u32:8: 1092] sc_charger_calculate_voltage: vbat=3832mV vbat_dcic=3832mV vbat_diff=0mV",
"Line 14870: [  112.164804] [0:  kworker/u32:8: 1092] sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8400000 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 15097: [  112.814421] [5:  kworker/u32:8: 1092] sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8400000 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 15104: [  112.871463] [0:  kworker/u32:3:   93] sc_charger_monitor_work: state(PRESET_DC), iin_cc(1000mA), v_float(4485mV), vbat(3825000uV), vin(8187500uV), iin(1128750uA), die_temp(250), vbat_dcic(3883750), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(5/8300mV/1000mA)",
"Line 15456: [  113.411148] [0:  kworker/u32:8: 1092] sc_charger_check_dcmode_status: iin:1935000 iin_target:4500000 vbat:3918000 vbat_target:4190000 power_uw:16060500 vbus:8037500 vbus_wpc:12500 vbat_dcic:3920000 vbat_reg:0",
"Line 15587: [  113.891501] [0:  kworker/u32:8: 1092] sc_charger_check_dcmode_status: iin:2355000 iin_target:4500000 vbat:3939000 vbat_target:4190000 power_uw:19923300 vbus:8118750 vbus_wpc:6250 vbat_dcic:3943750 vbat_reg:0",
"Line 15715: [  114.371716] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:2784375 iin_target:4500000 vbat:3961000 vbat_target:4190000 power_uw:23998080 vbus:8206250 vbus_wpc:12500 vbat_dcic:3965000 vbat_reg:0",
"Line 15846: [  114.851433] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:3211875 iin_target:4500000 vbat:3981000 vbat_target:4190000 power_uw:28192580 vbus:8287500 vbus_wpc:6250 vbat_dcic:3987500 vbat_reg:0",
"Line 15974: [  115.399407] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:3628125 iin_target:4500000 vbat:4004000 vbat_target:4190000 power_uw:32434320 vbus:8368750 vbus_wpc:6250 vbat_dcic:4007500 vbat_reg:0",
"Line 16105: [  115.876166] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:4053750 iin_target:4500000 vbat:4023000 vbat_target:4190000 power_uw:36882300 vbus:8450000 vbus_wpc:6250 vbat_dcic:4027500 vbat_reg:0",
"Line 16245: [  116.355342] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:4475625 iin_target:4500000 vbat:4042000 vbat_target:4190000 power_uw:41438500 vbus:8531250 vbus_wpc:6250 vbat_dcic:4050000 vbat_reg:0",
"Line 16379: [  116.807461] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:4468125 iin_target:4500000 vbat:4045000 vbat_target:4190000 power_uw:41373680 vbus:8537500 vbus_wpc:6250 vbat_dcic:4050000 vbat_reg:0",
"Line 16503: [  117.231497] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:4458750 iin_target:4500000 vbat:4048000 vbat_target:4190000 power_uw:41281080 vbus:8537500 vbus_wpc:6250 vbat_dcic:4051250 vbat_reg:0",
"Line 16538: [  119.367500] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:4479375 iin_target:4500000 vbat:4046000 vbat_target:4190000 power_uw:41475540 vbus:8537500 vbus_wpc:0 vbat_dcic:4051250 vbat_reg:0",
"Line 16558: [  121.515672] [0:  kworker/u32:5:  197] sc_charger_check_dcmode_status: iin:4415625 iin_target:4500000 vbat:4054000 vbat_target:4190000 power_uw:40882900 vbus:8550000 vbus_wpc:0 vbat_dcic:4057500 vbat_reg:0",
"Line 29987: 09-11 13:31:05.317  root  1092  1092 I sc_charger_check_vbatmin: iin_adc:1875 vbat_adc:3788000 vbus_adc:9093750 vbus_wpc_adc:12500 vbat_dcic_adc:3765000",
"Line 29996: 09-11 13:31:05.349  root    12    12 I sc_charger_monitor_work: state(CHECK_VBAT), iin_cc(0mA), v_float(4485mV), vbat(3761000uV), vin(9093750uV), iin(1875uA), die_temp(245), vbat_dcic(3776250), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(0/0mV/0mA)",
"Line 30216: 09-11 13:31:05.445  root  1092  1092 I sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3761000 vbus_adc:9087500 vbus_wpc_adc:12500 vbat_dcic_adc:3771250",
"Line 30412: 09-11 13:31:05.521  root  1092  1092 I sc_charger_calculate_voltage: vbat=3761mV vbat_dcic=3791mV vbat_diff=30mV",
"Line 30751: 09-11 13:31:06.018  root    13    13 I sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3786000 vbus_adc:16725000 vbus_wpc_adc:12500 vbat_dcic_adc:3778750",
"Line 30951: 09-11 13:31:06.569  root    13    13 I sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3786000 vbus_adc:16725000 vbus_wpc_adc:12500 vbat_dcic_adc:3778750",
"Line 31153: 09-11 13:31:06.689  root    13    13 I sc_charger_start_direct_charging: iin_adc:1530000 vbat_adc:3796000 vbus_adc:16437500 vbus_wpc_adc:6250 vbat_dcic_adc:3947500",
"Line 31348: 09-11 13:31:06.765  root    13    13 I sc_charger_calculate_voltage: vbat=3801mV vbat_dcic=3802mV vbat_diff=1mV",
"Line 31494: 09-11 13:31:07.204  root  1092  1092 I sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3798000 vbus_adc:12575000 vbus_wpc_adc:12500 vbat_dcic_adc:3802500",
"Line 31789: 09-11 13:31:07.756  root  1092  1092 I sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3798000 vbus_adc:12575000 vbus_wpc_adc:12500 vbat_dcic_adc:3802500",
"Line 32130: 09-11 13:31:08.354  root    12    12 I sc_charger_check_dcmode_status: iin:1627500 iin_target:3000000 vbat:3919000 vbat_target:4190000 power_uw:20174800 vbus:12206250 vbus_wpc:6250 vbat_dcic:3923750 vbat_reg:0",
"Line 32259: 09-11 13:31:08.834  root  1092  1092 I sc_charger_check_dcmode_status: iin:2000625 iin_target:3000000 vbat:3941000 vbat_target:4190000 power_uw:25280000 vbus:12381250 vbus_wpc:6250 vbat_dcic:3950000 vbat_reg:0",
"Line 32399: 09-11 13:31:09.362  root    13    13 I sc_charger_check_dcmode_status: iin:2336250 iin_target:3000000 vbat:3974000 vbat_target:4190000 power_uw:30087680 vbus:12556250 vbus_wpc:12500 vbat_dcic:3977500 vbat_reg:0",
"Line 32541: 09-11 13:31:09.826  root    12    12 I sc_charger_check_dcmode_status: iin:2681250 iin_target:3000000 vbat:3998000 vbat_target:4190000 power_uw:35174720 vbus:12731250 vbus_wpc:6250 vbat_dcic:4003750 vbat_reg:0",
"Line 32671: 09-11 13:31:10.306  root    93    93 I sc_charger_check_dcmode_status: iin:3046875 iin_target:3000000 vbat:4026000 vbat_target:4190000 power_uw:40694560 vbus:12906250 vbus_wpc:0 vbat_dcic:4030000 vbat_reg:0",
"Line 32799: 09-11 13:31:10.790  root  1092  1092 I sc_charger_check_dcmode_status: iin:3005625 iin_target:3000000 vbat:4027000 vbat_target:4190000 power_uw:40086700 vbus:12900000 vbus_wpc:6250 vbat_dcic:4030000 vbat_reg:0",
"Line 32935: 09-11 13:31:11.266  root    93    93 I sc_charger_check_dcmode_status: iin:2953125 iin_target:3000000 vbat:4025000 vbat_target:4190000 power_uw:39333960 vbus:12887500 vbus_wpc:6250 vbat_dcic:4030000 vbat_reg:0",
"Line 33064: 09-11 13:31:11.714  root    13    13 I sc_charger_check_dcmode_status: iin:2945625 iin_target:3000000 vbat:4028000 vbat_target:4190000 power_uw:39227400 vbus:12893750 vbus_wpc:6250 vbat_dcic:4031250 vbat_reg:0",
"Line 33187: 09-11 13:31:12.190  root    13    13 I sc_charger_check_dcmode_status: iin:2934375 iin_target:3000000 vbat:4030000 vbat_target:4190000 power_uw:39080880 vbus:12887500 vbus_wpc:6250 vbat_dcic:4033750 vbat_reg:0",
"Line 33314: 09-11 13:31:12.686  root  1092  1092 I sc_charger_check_dcmode_status: iin:2968125 iin_target:3000000 vbat:4032000 vbat_target:4190000 power_uw:39593120 vbus:12912500 vbus_wpc:12500 vbat_dcic:4037500 vbat_reg:0",
"Line 33595: 09-11 13:31:14.021  root  1092  1092 I sc_charger_start_direct_charging: iin_adc:2951250 vbat_adc:4038000 vbus_adc:12912500 vbus_wpc_adc:12500 vbat_dcic_adc:4040000",
"Line 33792: 09-11 13:31:14.098  root  1092  1092 I sc_charger_calculate_voltage: vbat=3832mV vbat_dcic=3835mV vbat_diff=3mV",
"Line 34029: 09-11 13:31:14.237  root  1092  1092 I sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3832000 vbus_adc:13475000 vbus_wpc_adc:12500 vbat_dcic_adc:3835000",
"Line 34224: 09-11 13:31:14.314  root  1092  1092 I sc_charger_calculate_voltage: vbat=3832mV vbat_dcic=3832mV vbat_diff=0mV",
"Line 34386: 09-11 13:31:14.755  root  1092  1092 I sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8400000 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 34613: 09-11 13:31:15.405  root  1092  1092 I sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8400000 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 34620: 09-11 13:31:15.462  root    93    93 I sc_charger_monitor_work: state(PRESET_DC), iin_cc(1000mA), v_float(4485mV), vbat(3825000uV), vin(8187500uV), iin(1128750uA), die_temp(250), vbat_dcic(3883750), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(5/8300mV/1000mA)",
"Line 34972: 09-11 13:31:16.001  root  1092  1092 I sc_charger_check_dcmode_status: iin:1935000 iin_target:4500000 vbat:3918000 vbat_target:4190000 power_uw:16060500 vbus:8037500 vbus_wpc:12500 vbat_dcic:3920000 vbat_reg:0",
"Line 35103: 09-11 13:31:16.482  root  1092  1092 I sc_charger_check_dcmode_status: iin:2355000 iin_target:4500000 vbat:3939000 vbat_target:4190000 power_uw:19923300 vbus:8118750 vbus_wpc:6250 vbat_dcic:3943750 vbat_reg:0",
"Line 35231: 09-11 13:31:16.962  root    93    93 I sc_charger_check_dcmode_status: iin:2784375 iin_target:4500000 vbat:3961000 vbat_target:4190000 power_uw:23998080 vbus:8206250 vbus_wpc:12500 vbat_dcic:3965000 vbat_reg:0",
"Line 35362: 09-11 13:31:17.442  root    93    93 I sc_charger_check_dcmode_status: iin:3211875 iin_target:4500000 vbat:3981000 vbat_target:4190000 power_uw:28192580 vbus:8287500 vbus_wpc:6250 vbat_dcic:3987500 vbat_reg:0",
"Line 35490: 09-11 13:31:17.990  root    93    93 I sc_charger_check_dcmode_status: iin:3628125 iin_target:4500000 vbat:4004000 vbat_target:4190000 power_uw:32434320 vbus:8368750 vbus_wpc:6250 vbat_dcic:4007500 vbat_reg:0",
"Line 35621: 09-11 13:31:18.466  root    93    93 I sc_charger_check_dcmode_status: iin:4053750 iin_target:4500000 vbat:4023000 vbat_target:4190000 power_uw:36882300 vbus:8450000 vbus_wpc:6250 vbat_dcic:4027500 vbat_reg:0",
"Line 35761: 09-11 13:31:18.946  root    13    13 I sc_charger_check_dcmode_status: iin:4475625 iin_target:4500000 vbat:4042000 vbat_target:4190000 power_uw:41438500 vbus:8531250 vbus_wpc:6250 vbat_dcic:4050000 vbat_reg:0",
"Line 35895: 09-11 13:31:19.398  root    93    93 I sc_charger_check_dcmode_status: iin:4468125 iin_target:4500000 vbat:4045000 vbat_target:4190000 power_uw:41373680 vbus:8537500 vbus_wpc:6250 vbat_dcic:4050000 vbat_reg:0",
"Line 36019: 09-11 13:31:19.822  root    93    93 I sc_charger_check_dcmode_status: iin:4458750 iin_target:4500000 vbat:4048000 vbat_target:4190000 power_uw:41281080 vbus:8537500 vbus_wpc:6250 vbat_dcic:4051250 vbat_reg:0",
"Line 36054: 09-11 13:31:21.958  root    93    93 I sc_charger_check_dcmode_status: iin:4479375 iin_target:4500000 vbat:4046000 vbat_target:4190000 power_uw:41475540 vbus:8537500 vbus_wpc:0 vbat_dcic:4051250 vbat_reg:0",
"Line 36074: 09-11 13:31:24.106  root   197   197 I sc_charger_check_dcmode_status: iin:4415625 iin_target:4500000 vbat:4054000 vbat_target:4190000 power_uw:40882900 vbus:8550000 vbus_wpc:0 vbat_dcic:4057500 vbat_reg:0",
"Line 49461: 09-11 13:31:05.317  root  1092  1092 I sc_charger_check_vbatmin: iin_adc:1875 vbat_adc:3788000 vbus_adc:9093750 vbus_wpc_adc:12500 vbat_dcic_adc:3765000",
"Line 49471: 09-11 13:31:05.349  root    12    12 I sc_charger_monitor_work: state(CHECK_VBAT), iin_cc(0mA), v_float(4485mV), vbat(3761000uV), vin(9093750uV), iin(1875uA), die_temp(245), vbat_dcic(3776250), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(0/0mV/0mA)",
"Line 49691: 09-11 13:31:05.445  root  1092  1092 I sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3761000 vbus_adc:9087500 vbus_wpc_adc:12500 vbat_dcic_adc:3771250",
"Line 49887: 09-11 13:31:05.521  root  1092  1092 I sc_charger_calculate_voltage: vbat=3761mV vbat_dcic=3791mV vbat_diff=30mV",
"Line 50226: 09-11 13:31:06.018  root    13    13 I sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3786000 vbus_adc:16725000 vbus_wpc_adc:12500 vbat_dcic_adc:3778750",
"Line 50426: 09-11 13:31:06.569  root    13    13 I sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3786000 vbus_adc:16725000 vbus_wpc_adc:12500 vbat_dcic_adc:3778750",
"Line 50628: 09-11 13:31:06.689  root    13    13 I sc_charger_start_direct_charging: iin_adc:1530000 vbat_adc:3796000 vbus_adc:16437500 vbus_wpc_adc:6250 vbat_dcic_adc:3947500",
"Line 50823: 09-11 13:31:06.765  root    13    13 I sc_charger_calculate_voltage: vbat=3801mV vbat_dcic=3802mV vbat_diff=1mV",
"Line 50969: 09-11 13:31:07.204  root  1092  1092 I sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3798000 vbus_adc:12575000 vbus_wpc_adc:12500 vbat_dcic_adc:3802500",
"Line 51264: 09-11 13:31:07.756  root  1092  1092 I sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3798000 vbus_adc:12575000 vbus_wpc_adc:12500 vbat_dcic_adc:3802500",
"Line 51605: 09-11 13:31:08.354  root    12    12 I sc_charger_check_dcmode_status: iin:1627500 iin_target:3000000 vbat:3919000 vbat_target:4190000 power_uw:20174800 vbus:12206250 vbus_wpc:6250 vbat_dcic:3923750 vbat_reg:0",
"Line 51734: 09-11 13:31:08.834  root  1092  1092 I sc_charger_check_dcmode_status: iin:2000625 iin_target:3000000 vbat:3941000 vbat_target:4190000 power_uw:25280000 vbus:12381250 vbus_wpc:6250 vbat_dcic:3950000 vbat_reg:0",
"Line 51874: 09-11 13:31:09.362  root    13    13 I sc_charger_check_dcmode_status: iin:2336250 iin_target:3000000 vbat:3974000 vbat_target:4190000 power_uw:30087680 vbus:12556250 vbus_wpc:12500 vbat_dcic:3977500 vbat_reg:0",
"Line 52014: 09-11 13:31:09.826  root    12    12 I sc_charger_check_dcmode_status: iin:2681250 iin_target:3000000 vbat:3998000 vbat_target:4190000 power_uw:35174720 vbus:12731250 vbus_wpc:6250 vbat_dcic:4003750 vbat_reg:0",
"Line 52144: 09-11 13:31:10.306  root    93    93 I sc_charger_check_dcmode_status: iin:3046875 iin_target:3000000 vbat:4026000 vbat_target:4190000 power_uw:40694560 vbus:12906250 vbus_wpc:0 vbat_dcic:4030000 vbat_reg:0",
"Line 52272: 09-11 13:31:10.790  root  1092  1092 I sc_charger_check_dcmode_status: iin:3005625 iin_target:3000000 vbat:4027000 vbat_target:4190000 power_uw:40086700 vbus:12900000 vbus_wpc:6250 vbat_dcic:4030000 vbat_reg:0",
"Line 52408: 09-11 13:31:11.266  root    93    93 I sc_charger_check_dcmode_status: iin:2953125 iin_target:3000000 vbat:4025000 vbat_target:4190000 power_uw:39333960 vbus:12887500 vbus_wpc:6250 vbat_dcic:4030000 vbat_reg:0",
"Line 52537: 09-11 13:31:11.714  root    13    13 I sc_charger_check_dcmode_status: iin:2945625 iin_target:3000000 vbat:4028000 vbat_target:4190000 power_uw:39227400 vbus:12893750 vbus_wpc:6250 vbat_dcic:4031250 vbat_reg:0",
"Line 52660: 09-11 13:31:12.190  root    13    13 I sc_charger_check_dcmode_status: iin:2934375 iin_target:3000000 vbat:4030000 vbat_target:4190000 power_uw:39080880 vbus:12887500 vbus_wpc:6250 vbat_dcic:4033750 vbat_reg:0",
"Line 52787: 09-11 13:31:12.686  root  1092  1092 I sc_charger_check_dcmode_status: iin:2968125 iin_target:3000000 vbat:4032000 vbat_target:4190000 power_uw:39593120 vbus:12912500 vbus_wpc:12500 vbat_dcic:4037500 vbat_reg:0",
"Line 53068: 09-11 13:31:14.021  root  1092  1092 I sc_charger_start_direct_charging: iin_adc:2951250 vbat_adc:4038000 vbus_adc:12912500 vbus_wpc_adc:12500 vbat_dcic_adc:4040000",
"Line 53265: 09-11 13:31:14.098  root  1092  1092 I sc_charger_calculate_voltage: vbat=3832mV vbat_dcic=3835mV vbat_diff=3mV",
"Line 53502: 09-11 13:31:14.237  root  1092  1092 I sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3832000 vbus_adc:13475000 vbus_wpc_adc:12500 vbat_dcic_adc:3835000",
"Line 53697: 09-11 13:31:14.314  root  1092  1092 I sc_charger_calculate_voltage: vbat=3832mV vbat_dcic=3832mV vbat_diff=0mV",
"Line 53859: 09-11 13:31:14.755  root  1092  1092 I sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8400000 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 54086: 09-11 13:31:15.405  root  1092  1092 I sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8400000 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 54093: 09-11 13:31:15.462  root    93    93 I sc_charger_monitor_work: state(PRESET_DC), iin_cc(1000mA), v_float(4485mV), vbat(3825000uV), vin(8187500uV), iin(1128750uA), die_temp(250), vbat_dcic(3883750), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(5/8300mV/1000mA)",
"Line 54445: 09-11 13:31:16.001  root  1092  1092 I sc_charger_check_dcmode_status: iin:1935000 iin_target:4500000 vbat:3918000 vbat_target:4190000 power_uw:16060500 vbus:8037500 vbus_wpc:12500 vbat_dcic:3920000 vbat_reg:0",
"Line 54576: 09-11 13:31:16.482  root  1092  1092 I sc_charger_check_dcmode_status: iin:2355000 iin_target:4500000 vbat:3939000 vbat_target:4190000 power_uw:19923300 vbus:8118750 vbus_wpc:6250 vbat_dcic:3943750 vbat_reg:0",
"Line 54704: 09-11 13:31:16.962  root    93    93 I sc_charger_check_dcmode_status: iin:2784375 iin_target:4500000 vbat:3961000 vbat_target:4190000 power_uw:23998080 vbus:8206250 vbus_wpc:12500 vbat_dcic:3965000 vbat_reg:0",
"Line 54835: 09-11 13:31:17.442  root    93    93 I sc_charger_check_dcmode_status: iin:3211875 iin_target:4500000 vbat:3981000 vbat_target:4190000 power_uw:28192580 vbus:8287500 vbus_wpc:6250 vbat_dcic:3987500 vbat_reg:0",
"Line 54963: 09-11 13:31:17.990  root    93    93 I sc_charger_check_dcmode_status: iin:3628125 iin_target:4500000 vbat:4004000 vbat_target:4190000 power_uw:32434320 vbus:8368750 vbus_wpc:6250 vbat_dcic:4007500 vbat_reg:0",
"Line 55094: 09-11 13:31:18.466  root    93    93 I sc_charger_check_dcmode_status: iin:4053750 iin_target:4500000 vbat:4023000 vbat_target:4190000 power_uw:36882300 vbus:8450000 vbus_wpc:6250 vbat_dcic:4027500 vbat_reg:0",
"Line 55234: 09-11 13:31:18.946  root    13    13 I sc_charger_check_dcmode_status: iin:4475625 iin_target:4500000 vbat:4042000 vbat_target:4190000 power_uw:41438500 vbus:8531250 vbus_wpc:6250 vbat_dcic:4050000 vbat_reg:0",
"Line 55368: 09-11 13:31:19.398  root    93    93 I sc_charger_check_dcmode_status: iin:4468125 iin_target:4500000 vbat:4045000 vbat_target:4190000 power_uw:41373680 vbus:8537500 vbus_wpc:6250 vbat_dcic:4050000 vbat_reg:0",
"Line 55492: 09-11 13:31:19.822  root    93    93 I sc_charger_check_dcmode_status: iin:4458750 iin_target:4500000 vbat:4048000 vbat_target:4190000 power_uw:41281080 vbus:8537500 vbus_wpc:6250 vbat_dcic:4051250 vbat_reg:0",
"Line 55527: 09-11 13:31:21.958  root    93    93 I sc_charger_check_dcmode_status: iin:4479375 iin_target:4500000 vbat:4046000 vbat_target:4190000 power_uw:41475540 vbus:8537500 vbus_wpc:0 vbat_dcic:4051250 vbat_reg:0",
"Line 55547: 09-11 13:31:24.106  root   197   197 I sc_charger_check_dcmode_status: iin:4415625 iin_target:4500000 vbat:4054000 vbat_target:4190000 power_uw:40882900 vbus:8550000 vbus_wpc:0 vbat_dcic:4057500 vbat_reg:0",
"Line 58359: [   44.807788] [1:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:2975625 iin_target:3000000 vbat:4021000 vbat_target:4190000 power_uw:39686500 vbus:12881250 vbus_wpc:6250 vbat_dcic:4025000 vbat_reg:0",
"Line 58483: [   45.219265] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:2970000 iin_target:3000000 vbat:4021000 vbat_target:4190000 power_uw:39619800 vbus:12881250 vbus_wpc:6250 vbat_dcic:4026250 vbat_reg:0",
"Line 58774: [   47.314445] [1:  kworker/u32:3:   93] sc_charger_start_direct_charging: iin_adc:2932500 vbat_adc:4028000 vbus_adc:12893750 vbus_wpc_adc:6250 vbat_dcic_adc:4032500",
"Line 58970: [   47.391174] [0:  kworker/u32:3:   93] sc_charger_calculate_voltage: vbat=4028mV vbat_dcic=3835mV vbat_diff=193mV",
"Line 58998: [   47.495211] [1:  kworker/u32:3:   93] sc_charger_calculate_voltage: vbat=4028mV vbat_dcic=3832mV vbat_diff=195mV",
"Line 58999: [   47.639264] [0:  kworker/u32:3:   93] sc_charger_calculate_voltage: vbat=3830mV vbat_dcic=3832mV vbat_diff=2mV",
"Line 59208: [   47.779115] [1:  kworker/u32:3:   93] sc_charger_start_direct_charging: iin_adc:1875 vbat_adc:3830000 vbus_adc:13481250 vbus_wpc_adc:12500 vbat_dcic_adc:3832500",
"Line 59405: [   47.855165] [5:  kworker/u32:3:   93] sc_charger_calculate_voltage: vbat=3830mV vbat_dcic=3831mV vbat_diff=1mV",
"Line 59560: [   48.325742] [0:  kworker/u32:5:  188] sc_charger_preset_config: before cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8393750 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 59597: [   48.803560] [0:  kworker/u32:1:   13] sc_charger_monitor_work: state(PRESET_DC), iin_cc(1000mA), v_float(4485mV), vbat(3825000uV), vin(8175000uV), iin(1130625uA), die_temp(250), vbat_dcic(3880000), 		wpc_vout_mv(-22), wpc_iout_ma(-22), pps_requested(5/8300mV/1000mA)",
"Line 59811: [   48.870008] [1:  kworker/u32:5:  188] sc_charger_preset_config: after cp_en: iin_adc:1875 vbat_adc:3826000 vbus_adc:8393750 vbus_wpc_adc:12500 vbat_dcic_adc:3830000",
"Line 60146: [   49.511549] [0:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:1918125 iin_target:4500000 vbat:3914000 vbat_target:4190000 power_uw:15919400 vbus:8031250 vbus_wpc:12500 vbat_dcic:3918750 vbat_reg:0",
"Line 60277: [   49.992037] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:2338125 iin_target:4500000 vbat:3932000 vbat_target:4190000 power_uw:19779480 vbus:8106250 vbus_wpc:6250 vbat_dcic:3937500 vbat_reg:0",
"Line 60405: [   50.472139] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:2754375 iin_target:4500000 vbat:3954000 vbat_target:4190000 power_uw:23739480 vbus:8187500 vbus_wpc:6250 vbat_dcic:3957500 vbat_reg:0",
"Line 60536: [   50.947473] [0:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:3183750 iin_target:4500000 vbat:3974000 vbat_target:4190000 power_uw:27946740 vbus:8268750 vbus_wpc:6250 vbat_dcic:3978750 vbat_reg:0",
"Line 60664: [   51.427529] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:3585000 iin_target:4500000 vbat:3981000 vbat_target:4190000 power_uw:32049900 vbus:8343750 vbus_wpc:12500 vbat_dcic:3998750 vbat_reg:0",
"Line 60793: [   51.939466] [0:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:4001250 iin_target:4500000 vbat:4014000 vbat_target:4190000 power_uw:36409100 vbus:8431250 vbus_wpc:12500 vbat_dcic:4018750 vbat_reg:0",
"Line 60937: [   52.420071] [0:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:4425000 iin_target:4500000 vbat:4032000 vbat_target:4190000 power_uw:40975500 vbus:8512500 vbus_wpc:6250 vbat_dcic:4037500 vbat_reg:0",
"Line 61071: [   52.907380] [0:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:4464375 iin_target:4500000 vbat:4038000 vbat_target:4190000 power_uw:41425920 vbus:8518750 vbus_wpc:0 vbat_dcic:4042500 vbat_reg:0",
"Line 61201: [   53.347391] [0:  kworker/u32:3:   93] sc_charger_check_dcmode_status: iin:4460625 iin_target:4500000 vbat:4040000 vbat_target:4190000 power_uw:41388800 vbus:8531250 vbus_wpc:0 vbat_dcic:4043750 vbat_reg:0",
"Line 61324: [   53.763870] [0:  kworker/u32:1:   13] sc_charger_check_dcmode_status: iin:4453125 iin_target:4500000 vbat:4041000 vbat_target:4190000 power_uw:41323840 vbus:8531250 vbus_wpc:0 vbat_dcic:4045000 vbat_reg:0",
"Line 61358: [   55.908415] [0:  kworker/u32:5:  188] sc_charger_check_dcmode_status: iin:4455000 iin_target:4500000 vbat:4043000 vbat_target:4190000 power_uw:41342400 vbus:8531250 vbus_wpc:0 vbat_dcic:4047500 vbat_reg:0"]

# %%
import re

for text in temp:
    # print(text)
    if "vbat:" in text:
        vbus_match = re.search(r'vbus:(\d+)', text)
        iin_match = re.search(r'iin:(\d+)', text)
        vbat_match = re.search(r'vbat:(\d+)', text)
        vbat_dcic_match = re.search(r'vbat_dcic:(\d+)', text)

        vbus_value = int(vbus_match.group(1)) if vbus_match else None
        iin_value = int(iin_match.group(1)) if iin_match else None
        vbat_value = int(vbat_match.group(1)) if vbat_match else None
        vbat_dcic_value = int(vbat_dcic_match.group(1)) if vbat_dcic_match else None

        print(f"{vbus_value/1000}, {iin_value/1000}, {vbat_value/1000}, {vbat_dcic_value/1000}, {(vbat_value-vbat_dcic_value)/1000}")

    elif "vbat=" in text:
        vbat_match = re.search(r'vbat=(\d+)', text)
        vbat_dcic_match = re.search(r'vbat_dcic=(\d+)', text)

        vbat_value = int(vbat_match.group(1)) if vbat_match else None
        vbat_dcic_value = int(vbat_dcic_match.group(1)) if vbat_dcic_match else None

        print(f"0, 0, {vbat_value}, {vbat_dcic_value}, {(vbat_value-vbat_dcic_value)}")

    elif "vbat_adc:" in text:
        vbus_match = re.search(r'vbus_adc:(\d+)', text)
        iin_match = re.search(r'iin_adc:(\d+)', text)
        vbat_match = re.search(r'vbat_adc:(\d+)', text)
        vbat_dcic_match = re.search(r'vbat_dcic_adc:(\d+)', text)

        vbus_value = int(vbus_match.group(1)) if vbus_match else None
        iin_value = int(iin_match.group(1)) if iin_match else None
        vbat_value = int(vbat_match.group(1)) if vbat_match else None
        vbat_dcic_value = int(vbat_dcic_match.group(1)) if vbat_dcic_match else None

        print(f"{vbus_value/1000}, {iin_value/1000}, {vbat_value/1000}, {vbat_dcic_value/1000}, {(vbat_value-vbat_dcic_value)/1000}")

    elif "vbat(" in text:
        vbus_match = re.search(r'vin\((\d+)', text)
        iin_match = re.search(r'iin\((\d+)', text)
        vbat_match = re.search(r'vbat\((\d+)', text)
        vbat_dcic_match = re.search(r'vbat_dcic\((\d+)', text)

        vbus_value = int(vbus_match.group(1)) if vbus_match else None
        iin_value = int(iin_match.group(1)) if iin_match else None
        vbat_value = int(vbat_match.group(1)) if vbat_match else None
        vbat_dcic_value = int(vbat_dcic_match.group(1)) if vbat_dcic_match else None

        print(f"{vbus_value/1000}, {iin_value/1000}, {vbat_value/1000}, {vbat_dcic_value/1000}, {(vbat_value-vbat_dcic_value)/1000}")
    
    else:
        print(text)

# %%
len(temp)

# %%
sc_charger_set_new
