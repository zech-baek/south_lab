# %%
file = "./misc/regmap/sc85853_0p0_regmap.xlsx"

from misc.extract_regmap_v2 import extract_regmap
target_object = extract_regmap(filename=file, project="sc85853", revision="0p0")
target_object.extract()
# Out:
# addr1 0x00 VERSION_ID[3:0] : msb 7, lsb 4
# addr1 0x00 VERSION_ID[3:0] : msb 7, lsb 4
# addr1 0x00 VERSION_ID[3:0] : msb 7, lsb 4
# addr1 0x00 VERSION_ID[3:0] : msb 7, lsb 4
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x01 POR_FLAG : msb 7, lsb 7
# addr1 0x01 CP_SWITCHING_FLAG : msb 6, lsb 6
# addr1 0x01 VIN_IN_PRESENT_FLAG : msb 5, lsb 5
# addr1 0x01 VB_OUT_PRESENT_FLAG : msb 4, lsb 4
# addr1 0x01 VIN_IN_TH_CHG_EN_FLAG : msb 3, lsb 3
# addr1 0x01 VB_OUT_IN_TH_CHG_EN_FLAG : msb 2, lsb 2
# addr1 0x02 VEXT_INSERT_FLAG : msb 6, lsb 6
# addr1 0x02 VUSB_INSERT_FLAG : msb 5, lsb 5
# addr1 0x02 VEXT_REMOVE_FLAG : msb 4, lsb 4
# addr1 0x02 VUSB_REMOVE_FLAG : msb 3, lsb 3
# addr1 0x02 VOUT_TH_CHG_EN_FLAG : msb 2, lsb 2
# addr1 0x02 VOUT_TH_REV_EN_FLAG : msb 1, lsb 1
# addr1 0x02 VOUT_INSERT_FLAG : msb 0, lsb 0
# addr1 0x03 QB2_ON_FLAG : msb 5, lsb 5
# ...
