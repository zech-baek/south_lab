# %%
file = "./misc/regmap/sc83123_1p0_regmap.xlsx"

from misc.extract_regmap_v2 import extract_regmap
target_object = extract_regmap(filename=file, project="sc83123", revision="1p0")
target_object.extract()
# Out:
# addr1 0x00 DEVICE_REV[3:0] : msb 7, lsb 4
# addr1 0x00 DEVICE_REV[3:0] : msb 7, lsb 4
# addr1 0x00 DEVICE_REV[3:0] : msb 7, lsb 4
# addr1 0x00 DEVICE_REV[3:0] : msb 7, lsb 4
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x00 DEVICE_ID[3:0] : msb 3, lsb 0
# addr1 0x01 RESET : msb 7, lsb 7
# addr1 0x01 MODE_CFG : msb 6, lsb 6
# addr1 0x01 EN_OOA : msb 5, lsb 5
# addr1 0x01 FPWM_CFG : msb 4, lsb 4
# addr1 0x01 COMP_R[1:0] : msb 3, lsb 2
# addr1 0x01 COMP_R[1:0] : msb 3, lsb 2
# addr1 0x01 COMP_C[1:0] : msb 1, lsb 0
# addr1 0x01 COMP_C[1:0] : msb 1, lsb 0
# addr1 0x02 DEVICE_EN : msb 7, lsb 7
# addr1 0x02 VOUT_CONFIG : msb 6, lsb 6
# addr1 0x02 VOUT_REG[5:0] : msb 5, lsb 0
# addr1 0x02 VOUT_REG[5:0] : msb 5, lsb 0
# addr1 0x02 VOUT_REG[5:0] : msb 5, lsb 0
# addr1 0x02 VOUT_REG[5:0] : msb 5, lsb 0
# addr1 0x02 VOUT_REG[5:0] : msb 5, lsb 0
# addr1 0x02 VOUT_REG[5:0] : msb 5, lsb 0
# ...
