# %%
file = "./misc/regmap/sc8505_0p0_regmap.xlsx"

from misc.extract_regmap_v2 import extract_regmap
target_object = extract_regmap(filename=file, project="sc8505", revision="0p0")
target_object.extract()
# Out:
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x06 VBUS_OVP[6:0] : msb 6, lsb 0
# addr1 0x0a TSHUT_DIS : msb 7, lsb 7
# addr1 0x0f REG_RST : msb 7, lsb 7
# addr1 0x10 FSW_SET[2:0] : msb 7, lsb 5
# addr1 0x10 FSW_SET[2:0] : msb 7, lsb 5
# addr1 0x10 FSW_SET[2:0] : msb 7, lsb 5
# addr1 0x10 WD_TIMEOUT[1:0] : msb 4, lsb 3
# addr1 0x10 WD_TIMEOUT[1:0] : msb 4, lsb 3
# addr1 0x10 WD_TIMEOUT_DIS : msb 2, lsb 2
# addr1 0x12 VOUT_OVP_DIS : msb 7, lsb 7
# addr1 0x12 VOUT_OVP[1:0] : msb 6, lsb 5
# addr1 0x12 VOUT_OVP[1:0] : msb 6, lsb 5
# addr1 0x12 FREQ_SHIFT[1:0] : msb 4, lsb 3
# addr1 0x12 FREQ_SHIFT[1:0] : msb 4, lsb 3
# addr1 0x12 MS[1:0] : msb 1, lsb 0
# addr1 0x12 MS[1:0] : msb 1, lsb 0
# addr1 0x13 VOUT_OVP_STAT : msb 5, lsb 5
# addr1 0x13 VBUS_OVP_STAT : msb 1, lsb 1
# ...
