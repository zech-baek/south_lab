# %%
from interface.cui_logger import logger as log

# %%
log.scan_uart()
# Out:
# available serial/usb ports:
# ------------------------------------------------------------
# port: COM10
# name: COM10
# description: 표준 Bluetooth에서 직렬 링크(COM10)
# manufacturer: Microsoft
# product: None
# hwid: BTHENUM\{00001101-0000-1000-8000-00805F9B34FB}_LOCALMFG&0000\7&26D3A56&0&000000000000_00000000
# ------------------------------------------------------------
# port: COM11
# name: COM11
# description: 표준 Bluetooth에서 직렬 링크(COM11)
# manufacturer: Microsoft
# product: None
# hwid: BTHENUM\{00001101-0000-1000-8000-00805F9B34FB}_VID&000105D6_PID&000A\7&26D3A56&0&84AC608D9CBE_C00000000
# ------------------------------------------------------------
# port: COM8
# name: COM8
# description: USB-SERIAL CH340(COM8)
# manufacturer: wch.cn
# product: None
# hwid: USB VID:PID=1A86:7523 SER= LOCATION=1-3.1
# ------------------------------------------------------------
# {'COM10': {'port': 'COM10', 'name': 'COM10', 'pid': None, 'vid': None},
#  'COM11': {'port': 'COM11', 'name': 'COM11', 'pid': None, 'vid': None},
#  'COM8': {'port': 'COM8', 'name': 'COM8', 'pid': 29987, 'vid': 6790}}

# %%
# G28 : move to home
# G90 : absolute coordinate
# G91 : relative coordinate (not operational)
# G0 X10 : x-axis + 10mm
# G0 X-10 : x-axis - 10mm
# F number : moving speed (lower than 3000)
# G92 : set the current coordinate to 0
# max X : 240

# %%
import serial

ser = serial.Serial(
    port="COM8",
    baudrate=115200,
    timeout=1
)

while ser.in_waiting:
    print(ser.readline().decode().strip()) # make empty log

# %%
import time

def send(cmd):

    ser.write((cmd + "\n").encode())
    time.sleep(0.5)
    
    while ser.in_waiting:
        print(ser.readline().decode().strip())

# %%
send("G28") # origin

# %%
send("G90") # abs coordinate
# Out:
# ok

# %%
send("G0 X100") # moving
# Out:
# ok

# %%
send("G0 Y50 F300")
# Out:
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# echo:busy: processing
# X:0.00 Y:0.00 Z:0.00 E:0.00 Count X:0 Y:0 Z:0
# ok
# ok

# %%
send("G0 Z50 F300")
# Out:
# ok

# %%
ser.close()

# %%
send("G92 Y0")
# Out:
# X:100.00 Y:0.00 Z:50.00 E:0.00 Count X:8000 Y:0 Z:20000
# ok

# %%
send("G0 Y-50")
# Out:
# ok

# %%
send("G92 X0")

# %%
send("G0 X-10")
