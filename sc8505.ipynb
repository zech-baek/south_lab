# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc8505 import project

from time import sleep as delay
from interface.cui_logger import logger as log

if "ic" in globals():
    ic.close()

ic = project(device="sc8505", revision="0p0", emulator="ch341", logging=False, is_gui=False)
# Out:
# failed to initialize the dm6500
# failed to initialize the dm6500
# failed to initialize n6705
# failed to initialize tektronix dp series
# initialized the asd-906b connection to COM14
# failed to initialize it8511a
# initialized with i2c address 0x65 by default

# %%
ic.i2c_scan()
# Out:
# acked address list : [101]
# update i2c address : 0x65 --> 0x65
# [101]

# %%
ic.status_ctrl
# Out:
# Addr    Reg              Value    Bit7              Bit6               Bit5             Bit4             Bit3              Bit2                Bit1              Bit0
# ------  ---------------  -------  ----------------  -----------------  ---------------  ---------------  ----------------  ------------------  ----------------  --------------------
# 0x06    VBUS_OVP         0x50     RESERVED          VBUS_OVP           VBUS_OVP         VBUS_OVP         VBUS_OVP          VBUS_OVP            VBUS_OVP          VBUS_OVP
# 0x0a    TEMP_CTRL        0x00     TSHUT_DIS         RESERVED           RESERVED         RESERVED         RESERVED          RESERVED            RESERVED          RESERVED
# 0x0f    CTRL2            0x10     REG_RST           RESERVED           RESERVED         RESERVED         RESERVED          RESERVED            RESERVED          RESERVED
# 0x10    CTRL3            0x64     FSW_SET           FSW_SET            FSW_SET          WD_TIMEOUT       WD_TIMEOUT        WD_TIMEOUT_DIS      RESERVED          RESERVED
# 0x12    CTRL5            0x60     VOUT_OVP_DIS      VOUT_OVP           VOUT_OVP         FREQ_SHIFT       FREQ_SHIFT        RESERVED            MS                MS
# 0x1d    MASK1            0x00     RESERVED          RESERVED           VOUT_OVP_MASK    RESERVED         RESERVED          RESERVED            VBUS_OVP_MASK     RESERVED
# 0x1e    MASK2            0x00     RESERVED          RESERVED           RESERVED         RESERVED         RESERVED          PIN_DIAG_FAIL_MASK  RESERVED          RESERVED
# 0x20    MASK4            0x00     RESERVED          RESERVED           RESERVED         RESERVED         RESERVED          TSHUT_MASK          RESERVED          WD_TIMEOUT_MASK
# 0x40    CONFIG2          0x05     POR_FLAG          RESERVED           RESERVED         RESERVED         RESERVED          RESERVED            RESERVED          RESERVED
# 0x41    CTRL11           0x00     RESERVED          VBUS_OVP_DIS       BUS2OUT_OVP_DIS  BUS2OUT_UVP_DIS  RESERVED          RESERVED            RESERVED          RESERVED
# 0x42    BUS2OUT_OVP_UVP  0xec     BUS2OUT_UVP       BUS2OUT_UVP        BUS2OUT_UVP      BUS2OUT_OVP      BUS2OUT_OVP       BUS2OUT_OVP         BUS2OUT_UVP_FLAG  BUS2OUT_OVP_FLAG
# 0x43    DEGLITCH         0x01     RESERVED          RESERVED           RESERVED         RESERVED         BUS2OUT_UVP_MASK  BUS2OUT_OVP_MASK    RESERVED          VOUT_TH_SW_REGN_STAT
# 0x50    CTRL6            0x08     VBUS_UVLO_DIS     VBUS_UVLO_FALL_DG  RESERVED         DEVICE_VERSION   DEVICE_VERSION    SYNC_EN             RESERVED          RESERVED
# 0x53    MASK6            0x00     RESERVED          RESERVED           RESERVED         RESERVED         RESERVED          RESERVED            RESERVED          VBUS_UVLO_MASK
# 0x54    CTRL7            0xd0     SKIP_EN           REF_SKIP_R         REF_SKIP_R       REF_SKIP_R       Reserved          Reserved            SKIP_HYS          CS_2
# 0x55    CTRL8            0x00     VOUT_FORCE_ON_PD  VOUT_FORCE_OFF_PD  RESERVED         AUDIO_EN         AUDIO_FREQ        RESERVED            RESERVED          RESERVED

# %%
ic.SKIP_EN =0

# %%
ic.status
# Out:
# Addr    Reg        Value    Bit7       Bit6               Bit5           Bit4       Bit3       Bit2                Bit1           Bit0
# ------  ---------  -------  ---------  -----------------  -------------  ---------  ---------  ------------------  -------------  ---------------
# 0x13    STAT1      0x00     RESERVED   RESERVED           VOUT_OVP_STAT  RESERVED   RESERVED   RESERVED            VBUS_OVP_STAT  RESERVED
# 0x14    STAT2      0x00     RESERVED   RESERVED           RESERVED       RESERVED   RESERVED   PIN_DIAG_FAIL_STAT  RESERVED       RESERVED
# 0x16    STAT4      0x00     RESERVED   RESERVED           RESERVED       RESERVED   RESERVED   RESERVED            RESERVED       RESERVED
# 0x17    STAT5      0x40     RESERVED   CP_SWITCHING_STAT  RESERVED       RESERVED   RESERVED   RESERVED            RESERVED       RESERVED
# 0x18    FLAG1      0x00     RESERVED   RESERVED           VOUT_OVP_FLAG  RESERVED   RESERVED   RESERVED            VBUS_OVP_FLAG  RESERVED
# 0x19    FLAG2      0x00     RESERVED   RESERVED           RESERVED       RESERVED   RESERVED   PIN_DIAG_FAIL_FLAG  RESERVED       RESERVED
# 0x1b    FLAG4      0x00     RESERVED   RESERVED           RESERVED       RESERVED   RESERVED   TSHUT_FLAG          RESERVED       WD_TIMEOUT_FLAG
# 0x22    PART_INFO  0x75     DEVICE_ID  DEVICE_ID          DEVICE_ID      DEVICE_ID  DEVICE_ID  DEVICE_ID           DEVICE_ID      DEVICE_ID
# 0x51    FLAG6      0x00     RESERVED   RESERVED           RESERVED       RESERVED   RESERVED   RESERVED            RESERVED       VBUS_UVLO_FLAG
# 0x52    STATE6     0x00     RESERVED   RESERVED           RESERVED       RESERVED   RESERVED   RESERVED            RESERVED       VBUS_UVLO_STAT
