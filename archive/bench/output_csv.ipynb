# %%
#-------------------------------------
# csv logging example
#-------------------------------------

# %%
#-------------------------------------
# import required package
#-------------------------------------

from interface.cui_logger import logger as log

# %%
#-------------------------------------
# 1. set the file name
# 2. output the header line via list
#-------------------------------------

from interface.cui_logger import logger as log

log.output_set_filename(title=f"filename")
log.output_csv(message=["VOUT_set (V)", "VOUT (V)", "IQ (uA)"])

# %%
#-------------------------------------
# output the data
#-------------------------------------

log.output_csv(message=[vout_set, vout_meas, iq_meas])
