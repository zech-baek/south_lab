# %% [markdown]
# # initial block

# %%
from equipment.equipment_init import *

# %% [markdown]
# # test code block

# %%
dm.current_10E_3

# %%
ds.horizontal_scale_grid = 2, 0

# %%
ds.ch1.vertical_scale_grid = 2, -3

# %%
ps1.cfg_all = 4, 0.1
