# %% [markdown]
# # I2C device initialization

# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc8563 import project

if "ic" in globals():
    ic.close()
    
ic = project(device="sc8563", revision="1p1", emulator="cp2112", logging=False, is_gui=False)
# Out:
# resource_name is None
# failed to initialize n6705
# initialized the scope connection
# initialized the asd-906b connection to COM14
# failed to initialize it8511a
# initialized with i2c address 0x6e by default

# %% [markdown]
# # test code

# %%
bs.vset = 4.0
bs.iset = 1.0
bs.enable

# %%
ic.i2c_scan()
# Out:
# acked address list : [111]
# update i2c address : 0x6e --> 0x6f
# [111]

# %%
# for D2D 1to1
ic.QB_EN = 1
ic.MODE=0x5
ic.PMID_IN_RANGE_DIS=0x0  
ic.SS_TIMEOUT=0x3  
ic.SS_FAIL_DIS=0x0  
ic.IIN_UCP_FALL_BLANKING_SET=0x0  
ic.IIN_UCP_EN_METHOD_SEL=0x0
ic.FREQ_SHIFT=0x0  
ic.FSW_SET=0x1  
ic.SYNC_EN=0x0  
ic.SYNC_ROLE=0x0  
ic.SYNC_OUT=0x0  
ic.SET_IBAT_SNS_RES=0x0  
ic.SET_IBAT_SNS_HS=0x0  
ic.PMID_PD_EN=0x0  
ic.VIN_PD_EN=0x0  
ic.REG_RST=0x0  
ic.VEXT_SHUT_DOWN_SET=0x0  
ic.STANDBY_MODE_SET=0x1
ic.WD_VEXT_SHUTDOWN_EN=0x0  
ic.WD_STANDBY_EN=0x0  
ic.WD_TIMEOUT_DIS=0x1  
ic.WD_TIMEOUT=0x3  
ic.EXT1_DISCHG_CTRL1=0x0  
ic.EXT1_DISCHG_CTRL2=0x0  
ic.EXT1_SW_CTRL1=0x0  
ic.EXT1_SW_CTRL2=0x0  
ic.EXT1_OVP=0x1
ic.EXT2_DISCHG_CTRL1=0x0  
ic.EXT2_DISCHG_CTRL2=0x0  
ic.EXT2_SW_CTRL1=0x1  
ic.EXT2_SW_CTRL2=0x0  
ic.EXT2_GATE_CTRL=0x1  
ic.EXT2_OVP=0x2
ic.EXT1_OVP_DIS=0x0  
ic.EXT2_OVP_DIS=0x0  
ic.DRV_SHORT_DET_DIS=0x0  
ic.FET_OPEN_DET_DIS=0x0  
ic.FET_OPEN=0x0  
ic.IIN_REG=0x54
ic.VBAT_REG=0xe0
ic.IBAT_REG_DIS=0x0  
ic.IIN_REG_DIS=0x1  
ic.VBAT_REG_DIS=0x1  
ic.IIN_UCP_CFG=0x1  
ic.TDIE_REG_DIS=0x1  
ic.IIN_TDIE_REG_INTERVAL=0x0  
ic.TDIE_REG=0x1  
ic.VBAT_OVP=0xf0
ic.IBAT_OCP_DIS=0x1  
ic.VIN_OVP_DIS=0x0  
ic.VIN_OVP=0x7  
ic.VOUT_OVP_DIS=0x0  
ic.VOUT_OVP=0x2
ic.IIN_OCP=0x58
ic.C1P2OUT_OVP_DIS=0x0  
ic.C1P2OUT_OVP_BLK=0x3  
ic.C1P2OUT_OVP_DG=0x0  
ic.C1P2OUT_OVP=0x3  
ic.C1P2OUT_UVP_DIS=0x0  
ic.C1P2OUT_UVP_BLK=0x0  
ic.C1P2OUT_UVP_DG=0x0  
ic.C1P2OUT_UVP=0x1  
ic.NTC_FLT_DIS=0x1  
ic.NTC_FLT=0x20  
ic.IIN_OCP_DIS=0x0  
ic.PIN_DIAG_FAIL_DIS=0x0  
ic.CFLY_OPEN_DIS=0x0  
ic.CFLY_SHORT_DIS=0x0  
ic.BST_FAIL_DIS=0x0  
ic.TSHUT_DIS=0x0  
ic.VBAT_OVP_DIS=0x0  
ic.IIN_UCP_DIS=0x0  
ic.IBAT_OCP_DG_SET=0x0  
ic.IIN_OCP_DG_SET=0x1  
ic.VBAT_OVP_DG_SET=0x0  
ic.VIN_OVP_DG_SET=0x0  
ic.VOUT_OVP_DG_SET=0x0  
ic.VEXT1_OVP_DG_SET=0x0  
ic.VEXT2_OVP_DG_SET=0x0  
ic.IIN_UCP_FALL_DG_SET=0x2  
ic.VOUT_TH_REV_FALL_DG_SET=0x0  
ic.VOUT_TH_CHG_FALL_DG_SET=0x0  
ic.ADC_EN=0x0  
ic.ADC_RATE=0x1  
ic.ADC_FREEZE=0x0  
ic.IIN_ADC_DIS=0x0  
ic.VIN_ADC_DIS=0x0  
ic.VEXT1_ADC_DIS=0x0  
ic.VEXT2_ADC_DIS=0x0  
ic.VOUT_ADC_DIS=0x0  
ic.VBAT_ADC_DIS=0x0  
ic.IBAT_ADC_DIS=0x1  
ic.C1P_ADC_DIS=0x0  
ic.NTC_ADC_DIS=0x1  
ic.TDIE_ADC_DIS=0x0

# %%
# for FWD
# ic.QB_EN = 1
ic.MODE=0x2
ic.PMID_IN_RANGE_DIS=0x0  
ic.SS_TIMEOUT=0x3  
ic.SS_FAIL_DIS=0x0  
ic.IIN_UCP_FALL_BLANKING_SET=0x0  
ic.IIN_UCP_EN_METHOD_SEL=0x0
ic.FREQ_SHIFT=0x0  
ic.FSW_SET=0x1  
ic.SYNC_EN=0x0  
ic.SYNC_ROLE=0x0  
ic.SYNC_OUT=0x0  
ic.SET_IBAT_SNS_RES=0x0  
ic.SET_IBAT_SNS_HS=0x0  
ic.PMID_PD_EN=0x0  
ic.VIN_PD_EN=0x0  
ic.REG_RST=0x0  
ic.VEXT_SHUT_DOWN_SET=0x0  
ic.STANDBY_MODE_SET=0x1
ic.WD_VEXT_SHUTDOWN_EN=0x0  
ic.WD_STANDBY_EN=0x0  
ic.WD_TIMEOUT_DIS=0x1  
ic.WD_TIMEOUT=0x3  
ic.EXT1_DISCHG_CTRL1=0x0  
ic.EXT1_DISCHG_CTRL2=0x0  
ic.EXT1_SW_CTRL1=0x0  
ic.EXT1_SW_CTRL2=0x0  
ic.EXT1_OVP=0x1
ic.EXT2_DISCHG_CTRL1=0x0  
ic.EXT2_DISCHG_CTRL2=0x0  
ic.EXT2_SW_CTRL1=0x1  
ic.EXT2_SW_CTRL2=0x0  
ic.EXT2_GATE_CTRL=0x1  
ic.EXT2_OVP=0x2
ic.EXT1_OVP_DIS=0x0  
ic.EXT2_OVP_DIS=0x0  
ic.DRV_SHORT_DET_DIS=0x0  
ic.FET_OPEN_DET_DIS=0x0  
ic.FET_OPEN=0x0  
ic.IIN_REG=0x54
ic.VBAT_REG=0xe0
ic.IBAT_REG_DIS=0x0  
ic.IIN_REG_DIS=0x1  
ic.VBAT_REG_DIS=0x1  
ic.IIN_UCP_CFG=0x1  
ic.TDIE_REG_DIS=0x1  
ic.IIN_TDIE_REG_INTERVAL=0x0  
ic.TDIE_REG=0x1  
ic.VBAT_OVP=0xf0
ic.IBAT_OCP_DIS=0x1  
ic.VIN_OVP_DIS=0x0  
ic.VIN_OVP=0x7  
ic.VOUT_OVP_DIS=0x0  
ic.VOUT_OVP=0x2
ic.IIN_OCP=0x58
ic.C1P2OUT_OVP_DIS=0x0  
ic.C1P2OUT_OVP_BLK=0x3  
ic.C1P2OUT_OVP_DG=0x0  
ic.C1P2OUT_OVP=0x3  
ic.C1P2OUT_UVP_DIS=0x0  
ic.C1P2OUT_UVP_BLK=0x0  
ic.C1P2OUT_UVP_DG=0x0  
ic.C1P2OUT_UVP=0x1  
ic.NTC_FLT_DIS=0x1  
ic.NTC_FLT=0x20  
ic.IIN_OCP_DIS=0x0  
ic.PIN_DIAG_FAIL_DIS=0x0  
ic.CFLY_OPEN_DIS=0x0  
ic.CFLY_SHORT_DIS=0x0  
ic.BST_FAIL_DIS=0x0  
ic.TSHUT_DIS=0x0  
ic.VBAT_OVP_DIS=0x0  
ic.IIN_UCP_DIS=0x1 ###################
ic.IBAT_OCP_DG_SET=0x0  
ic.IIN_OCP_DG_SET=0x1  
ic.VBAT_OVP_DG_SET=0x0  
ic.VIN_OVP_DG_SET=0x0  
ic.VOUT_OVP_DG_SET=0x0  
ic.VEXT1_OVP_DG_SET=0x0  
ic.VEXT2_OVP_DG_SET=0x0  
ic.IIN_UCP_FALL_DG_SET=0x2  
ic.VOUT_TH_REV_FALL_DG_SET=0x0  
ic.VOUT_TH_CHG_FALL_DG_SET=0x0  
ic.ADC_EN=0x0  
ic.ADC_RATE=0x1  
ic.ADC_FREEZE=0x0  
ic.IIN_ADC_DIS=0x0  
ic.VIN_ADC_DIS=0x0  
ic.VEXT1_ADC_DIS=0x0  
ic.VEXT2_ADC_DIS=0x0  
ic.VOUT_ADC_DIS=0x0  
ic.VBAT_ADC_DIS=0x0  
ic.IBAT_ADC_DIS=0x1  
ic.C1P_ADC_DIS=0x0  
ic.NTC_ADC_DIS=0x1  
ic.TDIE_ADC_DIS=0x0

# %%
ic.QB_EN=1
print(f"QB_EN : {ic.QB_EN}")
print(f"CP_EN : {ic.CP_EN}")

from time import sleep as delay
ds.single
delay(1)
ic.CP_EN=1
delay(1)
ic.CP_EN=0

# %%
ds.ch1.trigger_rise = 3
ds.horizontal_grid = 4

# %%
ds.save_waveform = "[SC8563] 1TO1 Start-up"

# %%
ds.ch1.vertical_scale_grid = 2, -3
ds.ch2.vertical_scale_grid = 2, -3
ds.ch3.vertical_scale_grid = 2, -3
ds.ch4.vertical_scale_grid = 2, -3

# %%
ds.label_off_batch = 1,2,3,4

# %%
ds.save_waveform = "TS12P - D2D #16 (1to2 timing)"

# %%
ds.save_waveform = "TS9 - D2D"

# %%
ic.QB_EN=1

# %%
ic.CP_EN = 1

# %%
ic.CP_EN = 0

# %%
ic.EXT2_SW_CTRL1 = 0
ic.EXT2_SW_CTRL2 = 1

# %%
ds.ch2.label = "SDA"

# %%
ic.EXT2_SW_CTRL2 = 0

# %%
print(f"EXT2_SW_CTRL1  :  {ic.EXT2_SW_CTRL1}")
print(f"EXT2_SW_CTRL2  :  {ic.EXT2_SW_CTRL2}")
print(f"EXT2_GATE_CTRL :  {ic.EXT2_GATE_CTRL}")
print(f"EXT2_OVP       :  {ic.EXT2_OVP}")

# %%
ic.ADC_EN = 1
ic.ADC_RATE = 0
ic.status_adc

# %%
ic.status

# %%
ic.MODE

# %%
ic.status_ctrl

# %%
ic.status_reg

# %%
ic.EXT2_SW_CTRL1 = 0
ic.EXT2_SW_CTRL2 = 0

# %%
ic.REG_RST = 1

# %%
ic.i2c_scan()

# %%
ic.VB_EN_STAT

# %%
ds.ch4.label = "VBUS"

# %%
ic.FSW_SET

# %%
ic.VB_EN_STAT
# Out:
# 1

# %%
ic.status
# Out:
# Addr    Reg           Value    Bit7                  Bit6               Bit5               Bit4                Bit3                  Bit2                  Bit1                  Bit0
# ------  ------------  -------  --------------------  -----------------  -----------------  ------------------  --------------------  --------------------  --------------------  -------------------
# 0x01    INT_DEVICE0   0x00     POR_FLAG              CP_SWITCHING_FLAG  QB_ON_FLAG         VIN_PRESENT_FLAG    VOUT_INSERT_FLAG      VOUT_TH_REV_EN_FLAG   VOUT_TH_CHG_EN_FLAG   VIN_TH_CHG_EN_FLAG
# 0x02    INT_DEVICE1   0x00     VEXT1_REMOVE_FLAG     VEXT2_REMOVE_FLAG  VEXT1_INSERT_FLAG  VEXT2_INSERT_FLAG   VEXT1_OVP_FLAG        VEXT2_OVP_FLAG        VEXT1_DRV_ON_FLAG     VEXT2_DRV_ON_FLAG
# 0x03    INT_DEVICE2   0x00     ADC_DONE_FLAG         IIN_UCP_RISE_FLAG  RESERVED           TDIE_REG_EXIT_FLAG  TDIE_REG_ACTIVE_FLAG  VBAT_REG_ACTIVE_FLAG  IBAT_REG_ACTIVE_FLAG  IIN_REG_ACTIVE_FLAG
# 0x04    INT_FAULT0    0x00     IIN_OCP_FLAG          IIN_UCP_FALL_FLAG  IBAT_OCP_FLAG      PMID_ERRORHI_FLAG   PMID_ERRORLO_FLAG     VIN_OVP_FLAG          VOUT_OVP_FLAG         VBAT_OVP_FLAG
# 0x05    INT_FAULT1    0x00     PIN_DIAG_FAIL_FLAG    CFLY_OPEN_FLAG     CFLY_SHORT_FLAG    BST_FAIL_FLAG       EXT1_DRV_SHORT_FLAG   EXT2_DRV_SHORT_FLAG   EXT1_FET_OPEN_FLAG    EXT2_FET_OPEN_FLAG
# 0x06    INT_FAULT2    0x00     CONV_OCP_FLAG         C1P2OUT_UVP_FLAG   C1P2OUT_OVP_FLAG   NTC_FLT_FLAG        TSHUT_FLAG            SS_FAIL_FLAG          SS_TIMEOUT_FLAG       WD_TIMEOUT_FLAG
# 0x07    MASK_DEVICE0  0x00     POR_MASK              CP_SWITCHING_MASK  QB_ON_MASK         VIN_PRESENT_MASK    VOUT_INSERT_MASK      VOUT_TH_REV_EN_MASK   VOUT_TH_CHG_EN_MASK   VIN_TH_CHG_EN_MASK
# 0x08    MASK_DEVICE1  0x00     VEXT1_REMOVE_MASK     VEXT2_REMOVE_MASK  VEXT1_INSERT_MASK  VEXT2_INSERT_MASK   VEXT1_OVP_MASK        VEXT2_OVP_MASK        VEXT1_DRV_ON_MASK     VEXT2_DRV_ON_MASK
# 0x09    MASK_DEVICE2  0x00     ADC_DONE_MASK         IIN_UCP_RISE_MASK  RESERVED           TDIE_REG_EXIT_MASK  TDIE_REG_ACTIVE_MASK  VBAT_REG_ACTIVE_MASK  IBAT_REG_ACTIVE_MASK  IIN_REG_ACTIVE_MASK
# 0x0a    MASK_FAULT0   0x00     IIN_OCP_MASK          IIN_UCP_FALL_MASK  IBAT_OCP_MASK      PMID_ERRORHI_MASK   PMID_ERRORLO_MASK     VIN_OVP_MASK          VOUT_OVP_MASK         VBAT_OVP_MASK
# 0x0b    MASK_FAULT1   0x00     PIN_DIAG_FAIL_MASK    CFLY_OPEN_MASK     CFLY_SHORT_MASK    BST_FAIL_MASK       EXT1_DRV_SHORT_MASK   EXT2_DRV_SHORT_MASK   EXT1_FET_OPEN_MASK    EXT2_FET_OPEN_MASK
# 0x0c    MASK_FAULT2   0x00     CONV_OCP_MASK         C1P2OUT_UVP_MASK   C1P2OUT_OVP_MASK   NTC_FLT_MASK        TSHUT_MASK            SS_FAIL_MASK          SS_TIMEOUT_MASK       WD_TIMEOUT_MASK
# 0x0d    STAT_DEVICE0  0x1f     RESERVED              CP_SWITCHING_STAT  QB_ON_STAT         VIN_PRESENT_STAT    VOUT_INSERT_STAT      VOUT_TH_REV_EN_STAT   VOUT_TH_CHG_EN_STAT   VIN_TH_CHG_EN_STAT
# 0x0e    STAT_DEVICE1  0xa2     VOUT_TH_SW_AVDD_STAT  RESERVED           VEXT1_INSERT_STAT  VEXT2_INSERT_STAT   VEXT1_OVP_STAT        VEXT2_OVP_STAT        VEXT1_DRV_ON_STAT     VEXT2_DRV_ON_STAT
# 0x0f    STAT_DEVICE2  0x00     ADC_DONE_STAT         IIN_UCP_RISE_STAT  RESERVED           RESERVED            TDIE_REG_ACTIVE_STAT  VBAT_REG_ACTIVE_STAT  IBAT_REG_ACTIVE_STAT  IIN_REG_ACTIVE_STAT
# 0x10    STAT_FAULT0   0x00     IIN_OCP_STAT          IIN_UCP_FALL_STAT  IBAT_OCP_STAT      PMID_ERRORHI_STAT   PMID_ERRORLO_STAT     VIN_OVP_STAT          VOUT_OVP_STAT         VBAT_OVP_STAT
# 0x11    STAT_FAULT1   0x00     PIN_DIAG_FAIL_STAT    CFLY_OPEN_STAT     CFLY_SHORT_STAT    BST_FAIL_STAT       EXT1_DRV_SHORT_STAT   EXT2_DRV_SHORT_STAT   EXT1_FET_OPEN_STAT    EXT2_FET_OPEN_STAT
# 0x12    STAT_FAULT2   0x00     CONV_OCP_STAT         C1P2OUT_UVP_STAT   C1P2OUT_OVP_STAT   NTC_FLT_STAT        TSHUT_STAT            SS_FAIL_STAT          SS_TIMEOUT_STAT       WD_TIMEOUT_STAT

# %%
print(f"EXT2_SW_CTRL1 : {ic.EXT2_SW_CTRL1}")
print(f"EXT2_SW_CTRL2 : {ic.EXT2_SW_CTRL2}")
ic.EXT2_SW_CTRL1 = 0
ic.EXT2_SW_CTRL2 = 1
print(f"EXT2_SW_CTRL1 : {ic.EXT2_SW_CTRL1}")
print(f"EXT2_SW_CTRL2 : {ic.EXT2_SW_CTRL2}")
# Out:
# EXT2_SW_CTRL1 : 1
# EXT2_SW_CTRL2 : 0
# EXT2_SW_CTRL1 : 0
# EXT2_SW_CTRL2 : 1

# %%
ic.EXT2_SW_CTRL1 = 0
ic.EXT2_SW_CTRL2 = 1

# %%
print(f"EXT2_SW_CTRL1 : {ic.EXT2_SW_CTRL1}")
print(f"EXT2_SW_CTRL2 : {ic.EXT2_SW_CTRL2}")
# Out:
# EXT2_SW_CTRL1 : 0
# EXT2_SW_CTRL2 : 1
