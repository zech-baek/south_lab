# %% [markdown]
# # I2C device initialization

# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc8563 import project

if "ic" in globals():
    ic.close()
    
ic = project(device="sc8563", revision="1p1", emulator="cp2112", logging=False, is_gui=False)

# %% [markdown]
# # test code

# %%
ic.i2c_scan()

# %%
ic.status

# %%
ic.status_adc

# %%
ds.init_default

# %%
ds.ch1.vertical_scale_grid = 3, -3
ds.ch2.vertical_scale_grid = 3, -3

# %%
ic.status

# %%
ic.write_byte(0x07, 0xff)
ic.write_byte(0x08, 0x7f)
ic.write_byte(0x09, 0xff)
ic.write_byte(0x0a, 0xff)
ic.write_byte(0x0b, 0xff)
ic.write_byte(0x0c, 0xff)
ic.EXT1_OVP = 7

# %%
ds.ch1.label = "VEXT1 (Connector side)"
ds.ch2.label = "VEXT1 (VEXT1 pin side)"
ds.ch3.label = "nINT (VEXT1_REMOVE_MASK)"

# %%
ds.save_waveform = "SC8563 - C_VEXT 20uF, VEXT1 discharging, unplug at 16V"

# %%
ic.ADC_EN = 0
ic.ADC_RATE = 0
# ic.ADC_FREEZE = 1

# %%
ic.ADC_EN = 0
ic.ADC_FREEZE = 0
ic.ADC_RATE = 0
ic.VEXT_SHUT_DOWN_SET = 0

# %%
ibat = dm.current_10E_6 * 1e+6
vext = ps.ch2.voltage
print(f"ADC_EN                : {ic.ADC_EN}")
print(f"ADC_RATE              : {ic.ADC_RATE}")
print(f"VEXT_SHUT_DOWN_SET    : {color.red}{ic.VEXT_SHUT_DOWN_SET}{color.end}")
# print(f"ADC_FREEZE  : {ic.ADC_FREEZE}")
print(f"VOUT_ADC              : {ic.vout_adc:.04f}V")
print(f"VBAT_ADC              : {ic.vbat_adc:.04f}V")
print(color.cyan+f"VEXT (V)              : {vext:.01f}V"+color.end)
print(color.blue+f"I_BATN (uA)           : {ibat:.03f}uA"+color.end)

# %%
ic.VBAT_ADC_DIS

# %%
ic.VBAT_REG_DIS = 1

# %%
ic.IIN_REG_DIS = 1

# %%
ic.VOUT_ADC_DIS = 1

# %%
ic.VEXT_SHUT_DOWN_SET

# %%
ic.REG_RST = 1

# %%
ic.status_adc

# %%
(0.05 / 100_000) * 1e+6

# %%
0.5e-6*100e+3

# %%
ic.status

# %%
ic.EXT1_OVP = 0

# %%
ic.VBAT_OVP_DIS

# %%
ic.STANDBY_MODE_SET = 1

# %%
ic.CP_EN = 1
