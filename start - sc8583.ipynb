# %% [markdown]
# # I2C device initialization

# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc8583 import project

if "ic" in globals():
    ic.close()
    
ic = project(device="sc8583", revision="1p1", emulator="ch341", logging=False, is_gui=False)
# Out:
# failed to initialize the dm6500
# failed to initialize the dm6500
# failed to initialize dp811
# failed to initialize tektronix dp series
# initialized the asd-906b connection to COM4
# initialized the it8511a connection to COM12
# [sc8583 __init__] initialized with i2c address 0x6e by default

# %% [markdown]
# # common

# %%
bs.vset = 4
bs.enable

# %%
ret = ic.i2c_scan()
ic.update_i2c_address(ret[0])

# %%
ds.ch1.vertical_grid = -3
ds.ch1.vertical_scale = 5

ds.ch2.vertical_grid = -3
ds.ch2.vertical_scale = 5

ds.ch3.vertical_grid = 1
ds.ch3.vertical_scale = 5

ds.ch4.vertical_grid = 3
ds.ch4.vertical_scale = 5


ds.enable_channel = 1, 2, 3, 4
ds.label_off_batch = 1, 2, 3, 4

# %% [markdown]
# # test code

# %%
ic.status

# %%
ps.cfg_all = 4*4 + 0.1, 0.1
ps.enable

# %%
ic.VEXT_OVP = 12

# %%
ic.STANDBY_MODE_SET = 1

# %%
ic.NTC_FLT_DIS = 1
ic.IIN_UCP_DIS = 0
ic.SS_TIMEOUT = 0
ic.C1P2OUT_UVP = 0

# %%
ic.C1P2OUT_UVP_DG

# %%
ic.enable_vin_charging

# %%
ps.iset = 0.01

# %%
ic.C1P2OUT_UVP

# %%
ic.write_byte(0x07, 0xff)
ic.write_byte(0x08, 0xff)
ic.write_byte(0x09, 0xff)
ic.write_byte(0x0a, 0xff)
ic.write_byte(0x0b, 0xff)
ic.write_byte(0x0c, 0xdf)

# %%
ds.ch4.trigger_fall = 1

# %%
ds.single

# %%
ds.save_waveform = "SC8583 - C1P2OUT_UVP, VIN, PMID, C1NA, INTB (C1P2OUT_UVP_MSK=0 only) #5"

# %%
ds.roll

# %%
ds.horizontal_scale = 1

# %%
ds.ch3.disable

# %%
ds.ch1.vertical_scale = 3
ds.ch4.vertical_scale = 1

# %%
ds.ch4.vertical_grid = -3

# %%
ic.read_byte(0x00)

# %%
hex(165)

# %%
log.scan_visa()

# %%
from concurrent.futures import ThreadPoolExecutor

id1 = 'USB0::0x05E6::0x6500::04651237::INSTR'
id2 = 'USB0::0x05E6::0x6500::04650960::INSTR'
id3 = 'USB0::0x05E6::0x6500::04651251::INSTR'

# %%
from phy.multimeter import keithley_dm6500 as dmm
from interface.cui_logger import logger as log
from time import sleep as delay
import time

dm1 = dmm(id1)
dm2 = dmm(id2)
dm3 = dmm(id3)

# %%
def func_iin():
    iin = dm3.voltage_1E_1 / 0.002
    return iin

def func_vbus_sub():
    vbus_sub  = dm2.voltage_100
    return vbus_sub

def func_vbus_main():
    vbus_main = dm1.voltage_100
    return vbus_main

start = time.time()

while True:
    lap = time.time() - start
    with ThreadPoolExecutor(max_workers=2) as executor:
        t_iin  = executor.submit(func_iin)
        t_sub  = executor.submit(func_vbus_sub)
        t_main = executor.submit(func_vbus_main)
        ret_iin  = t_iin.result()
        ret_sub  = t_sub.result()
        ret_main = t_main.result()
    print(f"{lap:.02f} {ret_iin:.06f} {ret_sub:.06f} {ret_main:.06f}")
    delay(0.2)

# %%
def func_iin():
    iin = dm3.voltage_1E_1 / 0.002
    return iin

def func_vbus_sub():
    vbus_sub  = dm2.voltage_10
    return vbus_sub

def func_vbus_main():
    vbus_main = dm1.voltage_1E_1 * 1000
    return vbus_main

start = time.time()

while True:
    lap = time.time() - start
    with ThreadPoolExecutor(max_workers=2) as executor:
        t_iin  = executor.submit(func_iin)
        t_sub  = executor.submit(func_vbus_sub)
        t_main = executor.submit(func_vbus_main)
        ret_iin  = t_iin.result()
        ret_sub  = t_sub.result()
        ret_main = t_main.result()
    print(f"{lap:.02f} {ret_iin:.06f} {ret_sub:.06f} {ret_main:.06f}")
    delay(0.2)

# %%
temp = {0x13:0x40,0x14:0x30,0x15:0x06,0x16:0x00,0x17:0x03,0x18:0x8c,0x19:0x00,0x1a:0x48,0x1b:0xc8,0x1c:0xe4,0x1d:0x59,0x1e:0xdc,0x1f:0xec,0x20:0x48,0x21:0x48,0x22:0x8d,0x23:0x40,0x24:0x63,0x25:0x81,0x26:0xa0,0x27:0x01,0x28:0x10,0x29:0x08,0x2a:0x80,0x2b:0x03}

# %%
ic.log_analyzer(temp)
# Out:
# Addr    Reg             Value    Bit7             Bit6                  Bit5              Bit4                 Bit3                 Bit2                       Bit1                       Bit0
# ------  --------------  -------  ---------------  --------------------  ----------------  -------------------  -------------------  -------------------------  -------------------------  ---------------------
# 0x13    CTRL0           0x40     CP_EN            QB_USB_EN             QB_WPC_EN         RSVD                 RSVD                 MODE                       MODE                       MODE
# 0x14    CTRL1           0x30     RSVD             RSVD                  SS_TIMEOUT        SS_TIMEOUT           SS_FAIL_DIS          IIN_UCP_FALL_BLANKING_SET  IIN_UCP_FALL_BLANKING_SET  IIN_UCP_EN_METHOD_SEL
# 0x15    CTRL2           0x06     RSVD             RSVD                  FREQ_SHIFT        FREQ_SHIFT           FSW_SET              FSW_SET                    FSW_SET                    FSW_SET
# 0x16    CTRL3           0x00     SYNC_EN          SYNC_ROLE             SYNC_OUT          SYNC_OUT             SET_IBAT_SNS_RES     SET_IBAT_SNS_HS            PMID_IN_RANGE_DIS          PMID_PD_EN
# 0x17    CTRL4           0x03     REG_RST          VEXT_SHUT_DOWN_SET    STANDBY_MODE_SET  WD_VEXT_SHUTDOWN_EN  WD_STANDBY_EN        WD_TIMEOUT_DIS             WD_TIMEOUT                 WD_TIMEOUT
# 0x18    VEXT_CTRL       0x8c     VEXT_MANUAL_EN   VEXT_DRV_ON           RSVD              VEXT_OVP_DIS         VEXT_OVP             VEXT_OVP                   VEXT_OVP                   VEXT_OVP
# 0x19    CTRL5           0x00     EXT_DISCHG_EN    EXT_AUTO_DISCHG_CTRL  RSVD              RSVD                 DRV_SHORT_DET_DIS    FET_OPEN_DET_DIS           FET_OPEN                   FET_OPEN
# 0x1a    IIN_REG         0x48     IIN_REG          IIN_REG               IIN_REG           IIN_REG              IIN_REG              IIN_REG                    IIN_REG                    IIN_REG
# 0x1b    VBAT_REG        0xc8     VBAT_REG         VBAT_REG              VBAT_REG          VBAT_REG             VBAT_REG             VBAT_REG                   VBAT_REG                   VBAT_REG
# 0x1c    IBAT_REG        0xe4     IBAT_REG_DIS     IBAT_REG              IBAT_REG          IBAT_REG             IBAT_REG             IBAT_REG                   IBAT_REG                   IBAT_REG
# 0x1d    REG_CTRL        0x59     IIN_REG_DIS      VBAT_REG_DIS          RSVD              IIN_UCP_CFG          TDIE_REG_DIS         IIN_TDIE_REG_INTERVAL      TDIE_REG                   TDIE_REG
# 0x1e    VBAT_OVP        0xdc     VBAT_OVP         VBAT_OVP              VBAT_OVP          VBAT_OVP             VBAT_OVP             VBAT_OVP                   VBAT_OVP                   VBAT_OVP
# 0x1f    IBAT_OCP        0xec     IBAT_OCP_DIS     IBAT_OCP              IBAT_OCP          IBAT_OCP             IBAT_OCP             IBAT_OCP                   IBAT_OCP                   IBAT_OCP
# 0x20    VIN_OVP         0x48     VIN_OVP_DIS      VIN_OVP               VIN_OVP           VIN_OVP              VIN_OVP              RSVD                       RSVD                       VIN_PD_EN
# 0x21    WPC_IN_OVP      0x48     WPC_IN_OVP_DIS   WPC_IN_OVP            WPC_IN_OVP        WPC_IN_OVP           WPC_IN_OVP           RSVD                       RSVD                       WPC_IN_PD_EN
# 0x22    IIN_OCP         0x8d     IIN_OCP          IIN_OCP               IIN_OCP           IIN_OCP              IIN_OCP              IIN_OCP                    IIN_OCP                    IIN_OCP
# 0x23    VOUT_OVP        0x40     VOUT_OVP_DIS     VOUT_OVP              VOUT_OVP          RSVD                 RSVD                 RSVD                       RSVD                       RSVD
# 0x24    C1P2OUT_OVP     0x63     C1P2OUT_OVP_DIS  C1P2OUT_OVP_BLK       C1P2OUT_OVP_BLK   C1P2OUT_OVP_DG       C1P2OUT_OVP_DG       C1P2OUT_OVP                C1P2OUT_OVP                C1P2OUT_OVP
# 0x25    C1P2OUT_UVP     0x81     C1P2OUT_UVP_DIS  C1P2OUT_UVP_BLK       C1P2OUT_UVP_BLK   C1P2OUT_UVP_DG       C1P2OUT_UVP_DG       C1P2OUT_UVP                C1P2OUT_UVP                C1P2OUT_UVP
# 0x26    NTC_FLT         0xa0     NTC_FLT_DIS      RSVD                  NTC_FLT           NTC_FLT              NTC_FLT              NTC_FLT                    NTC_FLT                    NTC_FLT
# 0x27    PROTECT_DIS     0x01     IIN_OCP_DIS      PIN_DIAG_FAIL_DIS     CFLY_OPEN_DIS     CFLY_SHORT_DIS       BST_FAIL_DIS         TSHUT_DIS                  VBAT_OVP_DIS               IIN_UCP_DIS
# 0x28    DEGLITCH_CTRL0  0x10     IBAT_OCP_DG_SET  IBAT_OCP_DG_SET       IIN_OCP_DG_SET    IIN_OCP_DG_SET       VBAT_OVP_DG_SET      VBAT_OVP_DG_SET            RSVD                       VOUT_OVP_DG_SET
# 0x29    DEGLITCH_CTRL1  0x08     VEXT_OVP_DG_SET  VEXT_OVP_DG_SET       VIN_OVP_DG_SET    WPC_IN_OVP_DG_SET    IIN_UCP_FALL_DG_SET  IIN_UCP_FALL_DG_SET        RSVD                       RSVD
# 0x2a    ADC_CTRL        0x80     ADC_EN           ADC_RATE              ADC_FREEZE        RSVD                 RSVD                 RSVD                       IIN_ADC_DIS                VIN_ADC_DIS
# 0x2b    ADC_FN_DISABLE  0x03     WPC_IN_ADC_DIS   VEXT_ADC_DIS          VOUT_ADC_DIS      VBAT_ADC_DIS         IBAT_ADC_DIS         C1P_ADC_DIS                NTC_ADC_DIS                TDIE_ADC_DIS
