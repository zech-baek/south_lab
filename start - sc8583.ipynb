# %% [markdown]
# # I2C device initialization

# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc8583 import project

if "ic" in globals():
    ic.close()
    
ic = project(device="sc8583", revision="1p1", emulator="ch341", logging=False, is_gui=False)

# %% [markdown]
# # test code

# %%
ps811.cfg_all = 8.4, 2
ps811.enable

# %%
i2c_ret = ic.i2c_scan(update=True)

# %%
ic.status

# %%
ic.MODE = 2
ic.IBAT_OCP_DIS = 1
ic.NTC_FLT_DIS = 1

# %%
ic.STANDBY_MODE_SET = 1
ic.enable_vin_charging

# %%
ic.status_adc

# %%
ic.disable_charging

# %%
ic.QB_USB_EN = 1

# %%
ic.QB_USB_EN

# %%
ic.QB_WPC_EN = 1

# %%
ic.QB_WPC_EN

# %%
ic.VEXT_OVP # 11V

# %%
ic.MODE = 2

# %%
ic.WPC_IN_OVP = 0

# %%
ps811.cfg_all = 12, 0.1

# %%
ic.status

# %%
ps811.cfg_all = 5, 0.1
