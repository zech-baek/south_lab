# %% [markdown]
# # I2C device initialization

# %%
# %matplotlib tk
from equipment.equipment_init import *
from project.sc8563 import project

if "ic" in globals():
    ic.close()
    
ic = project(device="sc8563", revision="1p1", emulator="ch341", logging=False, is_gui=False)
# Out:
# failed to initialize the dm6500
# failed to initialize the dm6500
# failed to initialize dp811
# failed to initialize tektronix dp series
# initialized the asd-906b connection to COM4
# initialized the it8511a connection to COM12
# [sc8563 __init__] initialized with i2c address 0x6e by default

# %% [markdown]
# # i2c scan

# %%
bs.vset = 3.6
bs.enable

# %%
ret = ic.i2c_scan()
# ic.update_i2c_address(ret[0])

# %% [markdown]
# # test code

# %%
ds.ch1.vertical_grid = -3
ds.ch1.vertical_scale = 3

# ds.ch2.vertical_grid = -3
# ds.ch2.vertical_scale = 2

# ds.ch3.vertical_grid = 1
# ds.ch3.vertical_scale = 2

ds.ch4.vertical_grid = -3
ds.ch4.vertical_scale =0.7


ds.enable_channel = 1, 2, 3, 4
ds.label_off_batch = 1, 2, 3, 4

# %%
ps.cfg_all = 3.6*3+0.2, 1
ps.enable

# %%
temp = {0x04 : 0x00, 0x05 : 0x00, 0x06 : 0x00, 0x07 : 0x00, 0x08 : 0x00, 0x09 : 0x00, 0x0a : 0x00, 0x0b : 0x00, 0x0c : 0x00, 0x0d : 0x7f, 0x0e : 0xb0, 0x0f : 0x40, 0x10 : 0x00, 0x11 : 0x08, 0x12 : 0x00, 0x13 : 0x90, 0x14 : 0x30, 0x15 : 0x08, 0x16 : 0x00, 0x17 : 0x23, 0x18 : 0x23, 0x19 : 0x0b, 0x1a : 0x00, 0x1b : 0x2e, 0x1c : 0xd8, 0x1d : 0x50, 0x1e : 0x09, 0x1f : 0xf0, 0x20 : 0xcc, 0x21 : 0x72, 0x22 : 0x58, 0x23 : 0x63, 0x24 : 0x01, 0x25 : 0xa0, 0x26 : 0x00, 0x27 : 0x10, 0x28 : 0x08, 0x29 : 0x40, 0x2a : 0x00, 0x2b : 0x00, 0x2c : 0xa7, 0x2d : 0x0a, 0x2e : 0x23, 0x2f : 0x0a, 0x30 : 0x25, 0x31 : 0x0a, 0x32 : 0x27, 0x33 : 0x0d, 0x34 : 0x77, 0x35 : 0x0d, 0x36 : 0x68, 0x3e : 0x02}

# %%
ic.log_analyzer(temp)
# Out:
# Addr    Reg                Value    Bit7                  Bit6                Bit5               Bit4                 Bit3                  Bit2                       Bit1                       Bit0
# ------  -----------------  -------  --------------------  ------------------  -----------------  -------------------  --------------------  -------------------------  -------------------------  -----------------------
# 0x04    INT_FAULT0         0x00     IIN_OCP_FLAG          IIN_UCP_FALL_FLAG   IBAT_OCP_FLAG      PMID_ERRORHI_FLAG    PMID_ERRORLO_FLAG     VIN_OVP_FLAG               VOUT_OVP_FLAG              VBAT_OVP_FLAG
# 0x05    INT_FAULT1         0x00     PIN_DIAG_FAIL_FLAG    CFLY_OPEN_FLAG      CFLY_SHORT_FLAG    BST_FAIL_FLAG        EXT1_DRV_SHORT_FLAG   EXT2_DRV_SHORT_FLAG        EXT1_FET_OPEN_FLAG         EXT2_FET_OPEN_FLAG
# 0x06    INT_FAULT2         0x00     CONV_OCP_FLAG         C1P2OUT_UVP_FLAG    C1P2OUT_OVP_FLAG   NTC_FLT_FLAG         TSHUT_FLAG            SS_FAIL_FLAG               SS_TIMEOUT_FLAG            WD_TIMEOUT_FLAG
# 0x07    MASK_DEVICE0       0x00     POR_MASK              CP_SWITCHING_MASK   QB_ON_MASK         VIN_PRESENT_MASK     VOUT_INSERT_MASK      VOUT_TH_REV_EN_MASK        VOUT_TH_CHG_EN_MASK        VIN_TH_CHG_EN_MASK
# 0x08    MASK_DEVICE1       0x00     VEXT1_REMOVE_MASK     VEXT2_REMOVE_MASK   VEXT1_INSERT_MASK  VEXT2_INSERT_MASK    VEXT1_OVP_MASK        VEXT2_OVP_MASK             VEXT1_DRV_ON_MASK          VEXT2_DRV_ON_MASK
# 0x09    MASK_DEVICE2       0x00     ADC_DONE_MASK         IIN_UCP_RISE_MASK   RESERVED           TDIE_REG_EXIT_MASK   TDIE_REG_ACTIVE_MASK  VBAT_REG_ACTIVE_MASK       IBAT_REG_ACTIVE_MASK       IIN_REG_ACTIVE_MASK
# 0x0a    MASK_FAULT0        0x00     IIN_OCP_MASK          IIN_UCP_FALL_MASK   IBAT_OCP_MASK      PMID_ERRORHI_MASK    PMID_ERRORLO_MASK     VIN_OVP_MASK               VOUT_OVP_MASK              VBAT_OVP_MASK
# 0x0b    MASK_FAULT1        0x00     PIN_DIAG_FAIL_MASK    CFLY_OPEN_MASK      CFLY_SHORT_MASK    BST_FAIL_MASK        EXT1_DRV_SHORT_MASK   EXT2_DRV_SHORT_MASK        EXT1_FET_OPEN_MASK         EXT2_FET_OPEN_MASK
# 0x0c    MASK_FAULT2        0x00     CONV_OCP_MASK         C1P2OUT_UVP_MASK    C1P2OUT_OVP_MASK   NTC_FLT_MASK         TSHUT_MASK            SS_FAIL_MASK               SS_TIMEOUT_MASK            WD_TIMEOUT_MASK
# 0x0d    STAT_DEVICE0       0x7f     RESERVED              CP_SWITCHING_STAT   QB_ON_STAT         VIN_PRESENT_STAT     VOUT_INSERT_STAT      VOUT_TH_REV_EN_STAT        VOUT_TH_CHG_EN_STAT        VIN_TH_CHG_EN_STAT
# 0x0e    STAT_DEVICE1       0xb0     VOUT_TH_SW_AVDD_STAT  RESERVED            VEXT1_INSERT_STAT  VEXT2_INSERT_STAT    VEXT1_OVP_STAT        VEXT2_OVP_STAT             VEXT1_DRV_ON_STAT          VEXT2_DRV_ON_STAT
# 0x0f    STAT_DEVICE2       0x40     ADC_DONE_STAT         IIN_UCP_RISE_STAT   RESERVED           RESERVED             TDIE_REG_ACTIVE_STAT  VBAT_REG_ACTIVE_STAT       IBAT_REG_ACTIVE_STAT       IIN_REG_ACTIVE_STAT
# 0x10    STAT_FAULT0        0x00     IIN_OCP_STAT          IIN_UCP_FALL_STAT   IBAT_OCP_STAT      PMID_ERRORHI_STAT    PMID_ERRORLO_STAT     VIN_OVP_STAT               VOUT_OVP_STAT              VBAT_OVP_STAT
# 0x11    STAT_FAULT1        0x08     PIN_DIAG_FAIL_STAT    CFLY_OPEN_STAT      CFLY_SHORT_STAT    BST_FAIL_STAT        EXT1_DRV_SHORT_STAT   EXT2_DRV_SHORT_STAT        EXT1_FET_OPEN_STAT         EXT2_FET_OPEN_STAT
# 0x12    STAT_FAULT2        0x00     CONV_OCP_STAT         C1P2OUT_UVP_STAT    C1P2OUT_OVP_STAT   NTC_FLT_STAT         TSHUT_STAT            SS_FAIL_STAT               SS_TIMEOUT_STAT            WD_TIMEOUT_STAT
# 0x13    CTRL0              0x90     CP_EN                 QB_EN               VB_EN_STAT         VB_EN_STAT           RESERVED              MODE                       MODE                       MODE
# 0x14    CTRL1              0x30     PMID_IN_RANGE_DIS     RESERVED            SS_TIMEOUT         SS_TIMEOUT           SS_FAIL_DIS           IIN_UCP_FALL_BLANKING_SET  IIN_UCP_FALL_BLANKING_SET  IIN_UCP_EN_METHOD_SEL
# 0x15    CTRL2              0x08     RESERVED              RESERVED            FREQ_SHIFT         FREQ_SHIFT           FSW_SET               FSW_SET                    FSW_SET                    FSW_SET
# 0x16    CTRL3              0x00     SYNC_EN               SYNC_ROLE           SYNC_OUT           SYNC_OUT             SET_IBAT_SNS_RES      SET_IBAT_SNS_HS            PMID_PD_EN                 VIN_PD_EN
# 0x17    CTRL4              0x23     REG_RST               VEXT_SHUT_DOWN_SET  STANDBY_MODE_SET   WD_VEXT_SHUTDOWN_EN  WD_STANDBY_EN         WD_TIMEOUT_DIS             WD_TIMEOUT                 WD_TIMEOUT
# 0x18    VEXT1_CTRL         0x23     EXT1_DISCHG_CTRL1     EXT1_DISCHG_CTRL2   EXT1_SW_CTRL1      EXT1_SW_CTRL2        RESERVED              EXT1_OVP                   EXT1_OVP                   EXT1_OVP
# 0x19    VEXT2_CTRL         0x0b     EXT2_DISCHG_CTRL1     EXT2_DISCHG_CTRL2   EXT2_SW_CTRL1      EXT2_SW_CTRL2        EXT2_GATE_CTRL        EXT2_OVP                   EXT2_OVP                   EXT2_OVP
# 0x1a    VEXT_PROTECT_CTRL  0x00     EXT1_OVP_DIS          EXT2_OVP_DIS        RESERVED           RESERVED             DRV_SHORT_DET_DIS     FET_OPEN_DET_DIS           FET_OPEN                   FET_OPEN
# 0x1b    IIN_REG            0x2e     IIN_REG               IIN_REG             IIN_REG            IIN_REG              IIN_REG               IIN_REG                    IIN_REG                    IIN_REG
# 0x1c    VBAT_REG           0xd8     VBAT_REG              VBAT_REG            VBAT_REG           VBAT_REG             VBAT_REG              VBAT_REG                   VBAT_REG                   VBAT_REG
# 0x1d    IBAT_REG           0x50     IBAT_REG_DIS          IBAT_REG            IBAT_REG           IBAT_REG             IBAT_REG              IBAT_REG                   IBAT_REG                   IBAT_REG
# 0x1e    REG_CTRL           0x09     IIN_REG_DIS           VBAT_REG_DIS        RESERVED           IIN_UCP_CFG          TDIE_REG_DIS          IIN_TDIE_REG_INTERVAL      TDIE_REG                   TDIE_REG
# 0x1f    VBAT_OVP           0xf0     VBAT_OVP              VBAT_OVP            VBAT_OVP           VBAT_OVP             VBAT_OVP              VBAT_OVP                   VBAT_OVP                   VBAT_OVP
# 0x20    IBAT_OCP           0xcc     IBAT_OCP_DIS          IBAT_REG            IBAT_REG           IBAT_REG             IBAT_REG              IBAT_REG                   IBAT_REG                   IBAT_REG
# 0x21    VIN_VOUT_OVP       0x72     VIN_OVP_DIS           VIN_OVP             VIN_OVP            VIN_OVP              RESERVED              VOUT_OVP_DIS               VOUT_OVP                   VOUT_OVP
# 0x22    IIN_OCP            0x58     IIN_OCP               IIN_OCP             IIN_OCP            IIN_OCP              IIN_OCP               IIN_OCP                    IIN_OCP                    IIN_OCP
# 0x23    C1P2OUT_OVP        0x63     C1P2OUT_OVP_DIS       C1P2OUT_OVP_BLK     C1P2OUT_OVP_BLK    C1P2OUT_OVP_DG       C1P2OUT_OVP_DG        C1P2OUT_OVP                C1P2OUT_OVP                C1P2OUT_OVP
# 0x24    C1P2OUT_UVP        0x01     C1P2OUT_UVP_DIS       C1P2OUT_UVP_BLK     C1P2OUT_UVP_BLK    C1P2OUT_UVP_DG       C1P2OUT_UVP_DG        C1P2OUT_UVP                C1P2OUT_UVP                C1P2OUT_UVP
# 0x25    NTC_FLT            0xa0     NTC_FLT_DIS           RESERVED            NTC_FLT            NTC_FLT              NTC_FLT               NTC_FLT                    NTC_FLT                    NTC_FLT
# 0x26    PROTECT_DIS        0x00     IIN_OCP_DIS           PIN_DIAG_FAIL_DIS   CFLY_OPEN_DIS      CFLY_SHORT_DIS       BST_FAIL_DIS          TSHUT_DIS                  VBAT_OVP_DIS               IIN_UCP_DIS
# 0x27    DEGLITCH_CTRL0     0x10     IBAT_OCP_DG_SET       IBAT_OCP_DG_SET     IIN_OCP_DG_SET     IIN_OCP_DG_SET       VBAT_OVP_DG_SET       VBAT_OVP_DG_SET            VIN_OVP_DG_SET             VOUT_OVP_DG_SET
# 0x28    DEGLITCH_CTRL1     0x08     VEXT1_OVP_DG_SET      VEXT1_OVP_DG_SET    VEXT2_OVP_DG_SET   VEXT2_OVP_DG_SET     IIN_UCP_FALL_DG_SET   IIN_UCP_FALL_DG_SET        VOUT_TH_REV_FALL_DG_SET    VOUT_TH_CHG_FALL_DG_SET
# 0x29    ADC_EN             0x40     ADC_EN                ADC_RATE            ADC_FREEZE         RESERVED             RESERVED              RESERVED                   IIN_ADC_DIS                VIN_ADC_DIS
# 0x2a    ADC_FN_DISABLE     0x00     VEXT1_ADC_DIS         VEXT2_ADC_DIS       VOUT_ADC_DIS       VBAT_ADC_DIS         IBAT_ADC_DIS          C1P_ADC_DIS                NTC_ADC_DIS                TDIE_ADC_DIS
# 0x2b    IIN_ADC1           0x00     RESERVED              RESERVED            RESERVED           RESERVED             IIN_ADC               IIN_ADC                    IIN_ADC                    IIN_ADC
# 0x2c    IIN_ADC0           0xa7     IIN_ADC               IIN_ADC             IIN_ADC            IIN_ADC              IIN_ADC               IIN_ADC                    IIN_ADC                    IIN_ADC
# 0x2d    VIN_ADC1           0x0a     RESERVED              RESERVED            RESERVED           RESERVED             VIN_ADC               VIN_ADC                    VIN_ADC                    VIN_ADC
# 0x2e    VIN_ADC0           0x23     VIN_ADC               VIN_ADC             VIN_ADC            VIN_ADC              VIN_ADC               VIN_ADC                    VIN_ADC                    VIN_ADC
# 0x2f    VEXT1_ADC1         0x0a     RESERVED              RESERVED            RESERVED           RESERVED             VEXT1_ADC             VEXT1_ADC                  VEXT1_ADC                  VEXT1_ADC
# 0x30    VEXT1_ADC0         0x25     VEXT1_ADC             VEXT1_ADC           VEXT1_ADC          VEXT1_ADC            VEXT1_ADC             VEXT1_ADC                  VEXT1_ADC                  VEXT1_ADC
# 0x31    VEXT2_ADC1         0x0a     RESERVED              RESERVED            RESERVED           RESERVED             VEXT2_ADC             VEXT2_ADC                  VEXT2_ADC                  VEXT2_ADC
# 0x32    VEXT2_ADC0         0x27     VEXT2_ADC             VEXT2_ADC           VEXT2_ADC          VEXT2_ADC            VEXT2_ADC             VEXT2_ADC                  VEXT2_ADC                  VEXT2_ADC
# 0x33    VOUT_ADC1          0x0d     RESERVED              RESERVED            RESERVED           RESERVED             VOUT_ADC              VOUT_ADC                   VOUT_ADC                   VOUT_ADC
# 0x34    VOUT_ADC0          0x77     VOUT_ADC              VOUT_ADC            VOUT_ADC           VOUT_ADC             VOUT_ADC              VOUT_ADC                   VOUT_ADC                   VOUT_ADC
# 0x35    VBAT_ADC1          0x0d     RESERVED              RESERVED            RESERVED           RESERVED             VBAT_ADC              VBAT_ADC                   VBAT_ADC                   VBAT_ADC
# 0x36    VBAT_ADC0          0x68     VBAT_ADC              VBAT_ADC            VBAT_ADC           VBAT_ADC             VBAT_ADC              VBAT_ADC                   VBAT_ADC                   VBAT_ADC
# 0x3e    NTC_ADC0           0x02     NTC_ADC               NTC_ADC             NTC_ADC            NTC_ADC              NTC_ADC               NTC_ADC                    NTC_ADC                    NTC_ADC

# %%
# %matplotlib tk
from interface.docs.output_chart import plot
chart = plot()

chart.set_title = "ADC Log"
chart.set_single_plot
chart.set_xlabel = "Time (sec)"
chart.set_y_main_label = "Voltage (V)"
chart.add_main_item = "VEXT1"
chart.add_main_item = "VEXT2"
chart.add_main_item = "VIN"
chart.add_main_item = "VOUT"
chart.VEXT1.set_linewidth = 4
chart.VEXT2.set_linewidth = 3
chart.VIN.set_linewidth = 2
chart.VOUT.set_linewidth = 1
chart.VIN.set_line_dot
chart.VOUT.set_line_dot

with open("./log/adc.txt", "r", encoding="utf-8") as file:
    for line in file:
        split_str = line.split(" ")

        # print(split_str)

        ret = {
            "lap"   : None,
            "vext1" : None,
            "vext2" : None,
            "vin"   : None,
            "vout"  : None
        }
        for n in split_str:
            if "vext1=" in n:
                ret["vext1"] = n.strip("vext1=").strip("mV")
            elif "vext2=" in n:
                ret["vext2"] = n.strip("vext2=").strip("mV")
            elif "vin=" in n:
                ret["vin"] = n.strip("vin=").strip("mV")
            elif "vout=" in n:
                ret["vout"] = n.strip("vout=").strip("mV\n")
            else:
                cnt = n.count(':')
                if cnt == 2:
                    # temp = n.split(":")
                    # hour = float(temp[0])
                    # mnts = float(temp[1])
                    # secs = float(temp[2])
                    # ret["lap"] = secs + mnts*60 + hour*60*60
                    ret["lap"] = n
        
        if None not in ret.values():
            lap   = ret["lap"]
            vext1 = int(ret["vext1"])
            vext2 = int(ret["vext2"])
            vin   = int(ret["vin"])
            vout  = int(ret["vout"])

            print(lap, vext1, vext2, vin, vout)
            
            # chart.VEXT1.set_data = lap, vext1
            # chart.VEXT2.set_data = lap, vext2
            # chart.VIN.set_data = lap, vin
            # chart.VOUT.set_data = lap, vout
            # chart.output

# chart.save_plot = chart.set_title

# %%
with open("./log/mcdodo.txt", "r", encoding="utf-8") as file:
    for line in file:
        split_str = line.split(" ")
        if len(split_str) == 13:
            vext1 = split_str[9].strip("vext1=").strip("mV")
            vext2 = split_str[10].strip("vext2=").strip("mV")
            vin   = split_str[11].strip("vin=").strip("mV")
            vout  = split_str[12].strip("vout=").strip("mV\n")
        if len(split_str) == 15:
            vext1 = split_str[11].strip("vext1=").strip("mV")
            vext2 = split_str[12].strip("vext2=").strip("mV")
            vin   = split_str[13].strip("vin=").strip("mV")
            vout  = split_str[14].strip("vout=").strip("mV\n")
        print(vext1, vext2, vin, vout)

# %%
with open("./log/mcdodo.txt", "r", encoding="utf-8") as file:
    for line in file:
        split_str = line.split(" ")
        for splitted in split_str:
            if "[0x1e]" in splitted:
                print(splitted)

# %%
from interface.cui_colors import color

with open("./log/timeline.txt", "r", encoding="utf-8") as file:
    for line in file:
        split_str = line.split(" ")
        for splitted in split_str:
            if "vbat:" in splitted:
                vbat_volt = float(splitted.split(":")[1])
                if vbat_volt > 4490000:
                    txt = f"{split_str[3]} {split_str[4]} {split_str[5]} vbat_adc (fg) : {vbat_volt}  (***)"
                else:
                    txt = f"{split_str[3]} {split_str[4]} {split_str[5]} vbat_adc (fg) : {vbat_volt}"
                with open("./log/fg_vbat_adc.txt", "a", encoding="utf-8") as file:
                    file.write(f"{txt}\n")
