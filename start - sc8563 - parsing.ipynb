# %% [markdown]
# # I2C device initialization

# %%
from project.sc8563 import project

if "ic" in globals():
    ic.close()
    print(f"destroy the object")
    
ic = project(device="sc8563", revision="1p1", emulator="ch341", logging=False, is_gui=False)
# Out:
# [sc8563 __init__] initialized with i2c address 0x6e by default

# %% [markdown]
# # log analysis

# %%
file = "./log/dump.txt"
ic.step_1_matching(dump=file, vendor_keyword=False)

# %%
for n1 in [1,2,3]:
    ic.step_1_matching(dump=f"./log/dump{n1}.txt", vendor_keyword=False)
